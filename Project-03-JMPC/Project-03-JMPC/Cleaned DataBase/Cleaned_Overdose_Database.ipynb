# %%
#Importing our Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Reading our Data and Creating a DataFrame
Overdose_Deaths = pd.read_csv("VSRR_Provisional_Drug_Overdose_Death_Counts_20240930.csv")
Overdose_Deaths_df = pd.DataFrame(Overdose_Deaths)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19860\198924147.py:7: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   Overdose_Deaths = pd.read_csv("VSRR_Provisional_Drug_Overdose_Death_Counts_20240930.csv")

# %%
#Displaying our DataPoints
Overdose_Deaths_df
# Out:
#       State  Year  Month           Period  \
# 0        AK  2015  April  12 month-ending
# 1        AK  2015  April  12 month-ending
# 2        AK  2015  April  12 month-ending
# 3        AK  2015  April  12 month-ending
# 4        AK  2015  April  12 month-ending
# ...     ...   ...    ...              ...
# 68203    YC  2024  March  12 month-ending
# 68204    YC  2024  March  12 month-ending
# 68205    YC  2024  March  12 month-ending
# 68206    YC  2024  March  12 month-ending
# 68207    YC  2024  March  12 month-ending
#
#                                                Indicator   Data Value  \
# 0               Natural & semi-synthetic opioids (T40.2)          NaN
# 1             Synthetic opioids, excl. methadone (T40.4)          NaN
# 2      Natural, semi-synthetic, & synthetic opioids, ...          NaN
# 3                                        Cocaine (T40.5)          NaN
# 4          Psychostimulants with abuse potential (T43.6)          NaN
# ...                                                  ...          ...
# 68203      Psychostimulants with abuse potential (T43.6)   237.000000
# 68204                                     Heroin (T40.1)   618.000000
# 68205                        Opioids (T40.0-T40.4,T40.6)  2528.000000
# 68206           Natural & semi-synthetic opioids (T40.2)   387.000000
# 68207                       Percent with drugs specified    99.764151
#
#       Percent Complete  Percent Pending Investigation     State Name  \
# 0                  100                       0.000000         Alaska
# 1                  100                       0.000000         Alaska
# 2                  100                       0.000000         Alaska
# 3                  100                       0.000000         Alaska
# 4                  100                       0.000000         Alaska
# ...                ...                            ...            ...
# 68203              100                       0.405502  New York City
# 68204              100                       0.405502  New York City
# 68205              100                       0.405502  New York City
# 68206              100                       0.405502  New York City
# 68207              100                       0.405502  New York City
#
#                                                 Footnote Footnote Symbol  \
# 0      Numbers may differ from published reports usin...              **
# 1      Numbers may differ from published reports usin...              **
# 2      Numbers may differ from published reports usin...              **
# 3      Numbers may differ from published reports usin...              **
# 4      Numbers may differ from published reports usin...              **
# ...                                                  ...             ...
# 68203              Underreported due to incomplete data.               *
# 68204              Underreported due to incomplete data.               *
# 68205              Underreported due to incomplete data.               *
# 68206              Underreported due to incomplete data.               *
# 68207              Underreported due to incomplete data.               *
#
#        Predicted Value
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 68203            250.0
# 68204            648.0
# 68205           2653.0
# 68206            406.0
# 68207              NaN
#
# [68208 rows x 12 columns]

# %%
#Removing any NaN values we find within our rows
Clean_Overdose_df = Overdose_Deaths_df.dropna()
print(Clean_Overdose_df)
# Out:
#       State  Year     Month           Period  \
# 6        AK  2015     April  12 month-ending
# 15       AK  2015    August  12 month-ending
# 33       AK  2015  December  12 month-ending
# 41       AK  2015  February  12 month-ending
# 51       AK  2015   January  12 month-ending
# ...     ...   ...       ...              ...
# 68202    YC  2024     March  12 month-ending
# 68203    YC  2024     March  12 month-ending
# 68204    YC  2024     March  12 month-ending
# 68205    YC  2024     March  12 month-ending
# 68206    YC  2024     March  12 month-ending
#
#                                                Indicator  Data Value  \
# 6                         Number of Drug Overdose Deaths       126.0
# 15                        Number of Drug Overdose Deaths       124.0
# 33                        Number of Drug Overdose Deaths       121.0
# 41                        Number of Drug Overdose Deaths       127.0
# 51                        Number of Drug Overdose Deaths       126.0
# ...                                                  ...         ...
# 68202  Natural & semi-synthetic opioids, incl. methad...       654.0
# 68203      Psychostimulants with abuse potential (T43.6)       237.0
# 68204                                     Heroin (T40.1)       618.0
# 68205                        Opioids (T40.0-T40.4,T40.6)      2528.0
# 68206           Natural & semi-synthetic opioids (T40.2)       387.0
#
#       Percent Complete  Percent Pending Investigation     State Name  \
# 6                  100                       0.000000         Alaska
# 15                 100                       0.000000         Alaska
# 33                 100                       0.000000         Alaska
# 41                 100                       0.000000         Alaska
# 51                 100                       0.000000         Alaska
# ...                ...                            ...            ...
# 68202              100                       0.405502  New York City
# 68203              100                       0.405502  New York City
# 68204              100                       0.405502  New York City
# 68205              100                       0.405502  New York City
# 68206              100                       0.405502  New York City
#
#                                                 Footnote Footnote Symbol  \
# 6      Numbers may differ from published reports usin...              **
# 15     Numbers may differ from published reports usin...              **
# 33     Numbers may differ from published reports usin...              **
# 41     Numbers may differ from published reports usin...              **
# 51     Numbers may differ from published reports usin...              **
# ...                                                  ...             ...
# 68202              Underreported due to incomplete data.               *
# 68203              Underreported due to incomplete data.               *
# 68204              Underreported due to incomplete data.               *
# 68205              Underreported due to incomplete data.               *
# 68206              Underreported due to incomplete data.               *
#
#        Predicted Value
# 6                126.0
# 15               124.0
# 33               121.0
# 41               127.0
# 51               126.0
# ...                ...
# 68202            685.0
# 68203            250.0
# 68204            648.0
# 68205           2653.0
# 68206            406.0
#
# [40389 rows x 12 columns]

# %%
#Removing some columns we will not be needing
Clean_Overdose_df.drop(columns=['Footnote', 'Footnote Symbol', 'Period'], inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19860\3351364639.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Clean_Overdose_df.drop(columns=['Footnote', 'Footnote Symbol', 'Period'], inplace=True)

# %%
Clean_Overdose_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40389 entries, 6 to 68206
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State                          40389 non-null  object
#  1   Year                           40389 non-null  int64
#  2   Month                          40389 non-null  object
#  3   Indicator                      40389 non-null  object
#  4   Data Value                     40389 non-null  float64
#  5   Percent Complete               40389 non-null  object
#  6   Percent Pending Investigation  40389 non-null  float64
#  7   State Name                     40389 non-null  object
#  8   Predicted Value                40389 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 3.1+ MB

# %%
#Reorganizing our Columns to be better alligned
Clean_Overdose_df = Clean_Overdose_df[['State', 'State Name', 'Year', 'Month', 'Indicator', 'Data Value', 'Percent Complete', 'Percent Pending Investigation', 'Predicted Value']]

Clean_Overdose_df
# Out:
#       State     State Name  Year     Month  \
# 6        AK         Alaska  2015     April
# 15       AK         Alaska  2015    August
# 33       AK         Alaska  2015  December
# 41       AK         Alaska  2015  February
# 51       AK         Alaska  2015   January
# ...     ...            ...   ...       ...
# 68202    YC  New York City  2024     March
# 68203    YC  New York City  2024     March
# 68204    YC  New York City  2024     March
# 68205    YC  New York City  2024     March
# 68206    YC  New York City  2024     March
#
#                                                Indicator  Data Value  \
# 6                         Number of Drug Overdose Deaths       126.0
# 15                        Number of Drug Overdose Deaths       124.0
# 33                        Number of Drug Overdose Deaths       121.0
# 41                        Number of Drug Overdose Deaths       127.0
# 51                        Number of Drug Overdose Deaths       126.0
# ...                                                  ...         ...
# 68202  Natural & semi-synthetic opioids, incl. methad...       654.0
# 68203      Psychostimulants with abuse potential (T43.6)       237.0
# 68204                                     Heroin (T40.1)       618.0
# 68205                        Opioids (T40.0-T40.4,T40.6)      2528.0
# 68206           Natural & semi-synthetic opioids (T40.2)       387.0
#
#       Percent Complete  Percent Pending Investigation  Predicted Value
# 6                  100                       0.000000            126.0
# 15                 100                       0.000000            124.0
# 33                 100                       0.000000            121.0
# 41                 100                       0.000000            127.0
# 51                 100                       0.000000            126.0
# ...                ...                            ...              ...
# 68202              100                       0.405502            685.0
# 68203              100                       0.405502            250.0
# 68204              100                       0.405502            648.0
# 68205              100                       0.405502           2653.0
# 68206              100                       0.405502            406.0
#
# [40389 rows x 9 columns]

# %%
#Displaying our final version of our DataFrame
print(Clean_Overdose_df)
# Out:
#       State     State Name  Year     Month  \
# 6        AK         Alaska  2015     April
# 15       AK         Alaska  2015    August
# 33       AK         Alaska  2015  December
# 41       AK         Alaska  2015  February
# 51       AK         Alaska  2015   January
# ...     ...            ...   ...       ...
# 68202    YC  New York City  2024     March
# 68203    YC  New York City  2024     March
# 68204    YC  New York City  2024     March
# 68205    YC  New York City  2024     March
# 68206    YC  New York City  2024     March
#
#                                                Indicator  Data Value  \
# 6                         Number of Drug Overdose Deaths       126.0
# 15                        Number of Drug Overdose Deaths       124.0
# 33                        Number of Drug Overdose Deaths       121.0
# 41                        Number of Drug Overdose Deaths       127.0
# 51                        Number of Drug Overdose Deaths       126.0
# ...                                                  ...         ...
# 68202  Natural & semi-synthetic opioids, incl. methad...       654.0
# 68203      Psychostimulants with abuse potential (T43.6)       237.0
# 68204                                     Heroin (T40.1)       618.0
# 68205                        Opioids (T40.0-T40.4,T40.6)      2528.0
# 68206           Natural & semi-synthetic opioids (T40.2)       387.0
#
#       Percent Complete  Percent Pending Investigation  Predicted Value
# 6                  100                       0.000000            126.0
# 15                 100                       0.000000            124.0
# 33                 100                       0.000000            121.0
# 41                 100                       0.000000            127.0
# 51                 100                       0.000000            126.0
# ...                ...                            ...              ...
# 68202              100                       0.405502            685.0
# 68203              100                       0.405502            250.0
# 68204              100                       0.405502            648.0
# 68205              100                       0.405502           2653.0
# 68206              100                       0.405502            406.0
#
# [40389 rows x 9 columns]

# %%
#Downloading our Data as a Json file for continued coding
Clean_Overdose_df.to_json("Cleaned_Overdose_Data", orient="records", lines=True)

# %%
####### Grouping the data by 'Indicator' and summing up 'Data Value' for each category

# %%
# Grouping the data by 'Indicator' and summing up 'Data Value' for each category
overdose_data = Clean_Overdose_df.groupby('Indicator')['Data Value'].sum()

# Filter out NaN values (if any)
overdose_data = overdose_data.dropna()

# Sort the data and select the top categories if needed
overdose_data = overdose_data.sort_values(ascending=False)

# Limit the number of slices 
top_overdose_data = overdose_data.head(10)

# %%
########

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_file
from bokeh.transform import cumsum
from bokeh.palettes import Category20c
import pandas as pd
import numpy as np

# Grouping the data by 'Indicator' and summing up 'Data Value' for each category
overdose_data = Clean_Overdose_df.groupby('Indicator')['Data Value'].sum()
overdose_data = overdose_data.dropna()
overdose_data = overdose_data.sort_values(ascending=False)

#  number of slices 
top_overdose_data = overdose_data.head(10)

# Convert data to a DataFrame and calculate angles
top_overdose_data_df = pd.DataFrame(top_overdose_data.reset_index(name='value'))
top_overdose_data_df['angle'] = top_overdose_data_df['value'] / top_overdose_data_df['value'].sum() * 2 * np.pi

# Calculate the percentage for hover display
top_overdose_data_df['percentage'] = (top_overdose_data_df['value'] / top_overdose_data_df['value'].sum()) * 100

# Use a palette that can handle more colors if needed (up to 20 categories with Category20c)
top_overdose_data_df['color'] = Category20c[len(top_overdose_data_df)]

# Create the pie chart figure
p = figure(height=600, width=600, title="Most Common Types of Overdoses in the US", toolbar_location=None,
           tools="hover", tooltips="@Indicator: @percentage{0.2f}%", x_range=(-0.5, 1.0))

# Add wedges (pie slices) based on the dynamic data
p.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='Indicator', source=top_overdose_data_df)

# Output to an HTML file
output_file("dynamic_overdose_percentage_pie_chart.html")

# Hide axis and grid lines
p.axis.axis_label = None
p.axis.visible = False
p.grid.grid_line_color = None

# Show the plot
show(p)

# %%
#  YEAR 2015-######################################## YEAR 2015 #########################

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_file
from bokeh.transform import cumsum
from bokeh.palettes import Category20c
import pandas as pd
import numpy as np

# Step 1: Pull data for the year 2015 
year = 2015
year_data = Clean_Overdose_df[Clean_Overdose_df['Year'] == year]

# Step 2: Group the data by 'Indicator' and sum 'Data Value' for the specific year
year_overdose_data = year_data.groupby('Indicator')['Data Value'].sum().dropna()

# Step 3: Convert data to a DataFrame and calculate angles for pie slices
year_overdose_data_df = pd.DataFrame(year_overdose_data.reset_index(name='value'))
year_overdose_data_df['angle'] = year_overdose_data_df['value'] / year_overdose_data_df['value'].sum() * 2 * np.pi
year_overdose_data_df['percentage'] = (year_overdose_data_df['value'] / year_overdose_data_df['value'].sum()) * 100

# Step 4: Set up colors (up to 20 slices, more categories need more colors)
year_overdose_data_df['color'] = Category20c[len(year_overdose_data_df)]

# Step 5: Create the pie chart
p = figure(height=600, width=600, title=f"Percentage of Drug Use {year}", toolbar_location=None,
           tools="hover", tooltips="@Indicator: @percentage{0.2f}%", x_range=(-0.5, 1.0))

# Add wedges (pie slices) based on the data
p.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='Indicator', source=year_overdose_data_df)

# Output to an HTML file
output_file(f"overdose_pie_chart_{year}.html")

# Hide axis and grid lines
p.axis.axis_label = None
p.axis.visible = False
p.grid.grid_line_color = None

# Show the plot
show(p)

# %%
#  YEAR  2016 ######################################## YEAR 2016 #########################

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_file
from bokeh.transform import cumsum
from bokeh.palettes import Category20c
import pandas as pd
import numpy as np

# Step 1: Pull data for the year 2016 
year = 2016
year_data = Clean_Overdose_df[Clean_Overdose_df['Year'] == year]

# Step 2: Group the data by 'Indicator' and sum 'Data Value' for the specific year
year_overdose_data = year_data.groupby('Indicator')['Data Value'].sum().dropna()

# Step 3: Convert data to a DataFrame and calculate angles for pie slices
year_overdose_data_df = pd.DataFrame(year_overdose_data.reset_index(name='value'))
year_overdose_data_df['angle'] = year_overdose_data_df['value'] / year_overdose_data_df['value'].sum() * 2 * np.pi
year_overdose_data_df['percentage'] = (year_overdose_data_df['value'] / year_overdose_data_df['value'].sum()) * 100

# Step 4: Set up colors (up to 20 slices, more categories need more colors)
year_overdose_data_df['color'] = Category20c[len(year_overdose_data_df)]

# Step 5: Create the pie chart
p = figure(height=600, width=600, title=f"Percentage of Drug Use {year}", toolbar_location=None,
           tools="hover", tooltips="@Indicator: @percentage{0.2f}%", x_range=(-0.5, 1.0))

# Add wedges (pie slices) based on the data
p.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='Indicator', source=year_overdose_data_df)

# Output to an HTML file
output_file(f"overdose_pie_chart_{year}.html")

# Hide axis and grid lines
p.axis.axis_label = None
p.axis.visible = False
p.grid.grid_line_color = None

# Show the plot
show(p)

# %%
#  YEAR  2017######################################## YEAR 2017 #########################

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_file
from bokeh.transform import cumsum
from bokeh.palettes import Category20c
import pandas as pd
import numpy as np

# Step 1: Pull data for the year 2017 
year = 2017
year_data = Clean_Overdose_df[Clean_Overdose_df['Year'] == year]

# Step 2: Group the data by 'Indicator' and sum 'Data Value' for the specific year
year_overdose_data = year_data.groupby('Indicator')['Data Value'].sum().dropna()

# Step 3: Convert data to a DataFrame and calculate angles for pie slices
year_overdose_data_df = pd.DataFrame(year_overdose_data.reset_index(name='value'))
year_overdose_data_df['angle'] = year_overdose_data_df['value'] / year_overdose_data_df['value'].sum() * 2 * np.pi
year_overdose_data_df['percentage'] = (year_overdose_data_df['value'] / year_overdose_data_df['value'].sum()) * 100

# Step 4: Set up colors (up to 20 slices, more categories need more colors)
year_overdose_data_df['color'] = Category20c[len(year_overdose_data_df)]

# Step 5: Create the pie chart
p = figure(height=600, width=600, title=f"Percentage of Drug Use {year}", toolbar_location=None,
           tools="hover", tooltips="@Indicator: @percentage{0.2f}%", x_range=(-0.5, 1.0))

# Add wedges (pie slices) based on the data
p.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='Indicator', source=year_overdose_data_df)

# Output to an HTML file
output_file(f"overdose_pie_chart_{year}.html")

# Hide axis and grid lines
p.axis.axis_label = None
p.axis.visible = False
p.grid.grid_line_color = None

# Show the plot
show(p)

# %%
# YEAR 2018######################################## YEAR 2018  #########################

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_file
from bokeh.transform import cumsum
from bokeh.palettes import Category20c
import pandas as pd
import numpy as np

# Step 1: Pull data for the year 2018 
year = 2018
year_data = Clean_Overdose_df[Clean_Overdose_df['Year'] == year]

# Step 2: Group the data by 'Indicator' and sum 'Data Value' for the specific year
year_overdose_data = year_data.groupby('Indicator')['Data Value'].sum().dropna()

# Step 3: Convert data to a DataFrame and calculate angles for pie slices
year_overdose_data_df = pd.DataFrame(year_overdose_data.reset_index(name='value'))
year_overdose_data_df['angle'] = year_overdose_data_df['value'] / year_overdose_data_df['value'].sum() * 2 * np.pi
year_overdose_data_df['percentage'] = (year_overdose_data_df['value'] / year_overdose_data_df['value'].sum()) * 100

# Step 4: Set up colors (up to 20 slices, more categories need more colors)
year_overdose_data_df['color'] = Category20c[len(year_overdose_data_df)]

# Step 5: Create the pie chart
p = figure(height=600, width=600, title=f"Percentage of Drug Use {year}", toolbar_location=None,
           tools="hover", tooltips="@Indicator: @percentage{0.2f}%", x_range=(-0.5, 1.0))

# Add wedges (pie slices) based on the data
p.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='Indicator', source=year_overdose_data_df)

# Output to an HTML file
output_file(f"overdose_pie_chart_{year}.html")

# Hide axis and grid lines
p.axis.axis_label = None
p.axis.visible = False
p.grid.grid_line_color = None

# Show the plot
show(p)

# %%
 # YEAR 2019######################################## YEAR 2019 #########################

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_file
from bokeh.transform import cumsum
from bokeh.palettes import Category20c
import pandas as pd
import numpy as np

# Step 1: Pull data for the year 2019 
year = 2019
year_data = Clean_Overdose_df[Clean_Overdose_df['Year'] == year]

# Step 2: Group the data by 'Indicator' and sum 'Data Value' for the specific year
year_overdose_data = year_data.groupby('Indicator')['Data Value'].sum().dropna()

# Step 3: Convert data to a DataFrame and calculate angles for pie slices
year_overdose_data_df = pd.DataFrame(year_overdose_data.reset_index(name='value'))
year_overdose_data_df['angle'] = year_overdose_data_df['value'] / year_overdose_data_df['value'].sum() * 2 * np.pi
year_overdose_data_df['percentage'] = (year_overdose_data_df['value'] / year_overdose_data_df['value'].sum()) * 100

# Step 4: Set up colors (up to 20 slices, more categories need more colors)
year_overdose_data_df['color'] = Category20c[len(year_overdose_data_df)]

# Step 5: Create the pie chart
p = figure(height=600, width=600, title=f"Percentage of Drug Use {year}", toolbar_location=None,
           tools="hover", tooltips="@Indicator: @percentage{0.2f}%", x_range=(-0.5, 1.0))

# Add wedges (pie slices) based on the data
p.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='Indicator', source=year_overdose_data_df)

# Output to an HTML file
output_file(f"overdose_pie_chart_{year}.html")

# Hide axis and grid lines
p.axis.axis_label = None
p.axis.visible = False
p.grid.grid_line_color = None

# Show the plot
show(p)

# %%
# YEAR 2020    ######################################## YEAR 2020  #########################

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_file
from bokeh.transform import cumsum
from bokeh.palettes import Category20c
import pandas as pd
import numpy as np

# Step 1: Pull data for the year 2020
year = 2020
year_data = Clean_Overdose_df[Clean_Overdose_df['Year'] == year]

# Step 2: Group the data by 'Indicator' and sum 'Data Value' for the specific year
year_overdose_data = year_data.groupby('Indicator')['Data Value'].sum().dropna()

# Step 3: Convert data to a DataFrame and calculate angles for pie slices
year_overdose_data_df = pd.DataFrame(year_overdose_data.reset_index(name='value'))
year_overdose_data_df['angle'] = year_overdose_data_df['value'] / year_overdose_data_df['value'].sum() * 2 * np.pi
year_overdose_data_df['percentage'] = (year_overdose_data_df['value'] / year_overdose_data_df['value'].sum()) * 100

# Step 4: Set up colors (up to 20 slices, more categories need more colors)
year_overdose_data_df['color'] = Category20c[len(year_overdose_data_df)]

# Step 5: Create the pie chart
p = figure(height=600, width=600, title=f"Percentage of Drug Use {year}", toolbar_location=None,
           tools="hover", tooltips="@Indicator: @percentage{0.2f}%", x_range=(-0.5, 1.0))

# Add wedges (pie slices) based on the data
p.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='Indicator', source=year_overdose_data_df)

# Output to an HTML file
output_file(f"overdose_pie_chart_{year}.html")

# Hide axis and grid lines
p.axis.axis_label = None
p.axis.visible = False
p.grid.grid_line_color = None

# Show the plot
show(p)

# %%
# YEAR 2021######################################## YEAR 2021 #########################

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_file
from bokeh.transform import cumsum
from bokeh.palettes import Category20c
import pandas as pd
import numpy as np

# Step 1: Pull data for the year 2021
year = 2021
year_data = Clean_Overdose_df[Clean_Overdose_df['Year'] == year]

# Step 2: Group the data by 'Indicator' and sum 'Data Value' for the specific year
year_overdose_data = year_data.groupby('Indicator')['Data Value'].sum().dropna()

# Step 3: Convert data to a DataFrame and calculate angles for pie slices
year_overdose_data_df = pd.DataFrame(year_overdose_data.reset_index(name='value'))
year_overdose_data_df['angle'] = year_overdose_data_df['value'] / year_overdose_data_df['value'].sum() * 2 * np.pi
year_overdose_data_df['percentage'] = (year_overdose_data_df['value'] / year_overdose_data_df['value'].sum()) * 100

# Step 4: Set up colors (up to 20 slices, more categories need more colors)
year_overdose_data_df['color'] = Category20c[len(year_overdose_data_df)]

# Step 5: Create the pie chart
p = figure(height=600, width=600, title=f"Percentage of Drug Use {year}", toolbar_location=None,
           tools="hover", tooltips="@Indicator: @percentage{0.2f}%", x_range=(-0.5, 1.0))

# Add wedges (pie slices) based on the data
p.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='Indicator', source=year_overdose_data_df)

# Output to an HTML file
output_file(f"overdose_pie_chart_{year}.html")

# Hide axis and grid lines
p.axis.axis_label = None
p.axis.visible = False
p.grid.grid_line_color = None

# Show the plot
show(p)

# %%
# YEAR 2022 ######################################## YEAR 2022 #########################

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_file
from bokeh.transform import cumsum
from bokeh.palettes import Category20c
import pandas as pd
import numpy as np

# Step 1: Pull data for the year 2022
year = 2022
year_data = Clean_Overdose_df[Clean_Overdose_df['Year'] == year]

# Step 2: Group the data by 'Indicator' and sum 'Data Value' for the specific year
year_overdose_data = year_data.groupby('Indicator')['Data Value'].sum().dropna()

# Step 3: Convert data to a DataFrame and calculate angles for pie slices
year_overdose_data_df = pd.DataFrame(year_overdose_data.reset_index(name='value'))
year_overdose_data_df['angle'] = year_overdose_data_df['value'] / year_overdose_data_df['value'].sum() * 2 * np.pi
year_overdose_data_df['percentage'] = (year_overdose_data_df['value'] / year_overdose_data_df['value'].sum()) * 100

# Step 4: Set up colors (up to 20 slices, more categories need more colors)
year_overdose_data_df['color'] = Category20c[len(year_overdose_data_df)]
custom_colors = ['#FF5733', '#33FF57', '#3357FF', '#FF33A1', '#F3FF33']
# Step 5: Create the pie chart
p = figure(height=600, width=600, title=f"Percentage of Drug Use {year}", toolbar_location=None,
           tools="hover", tooltips="@Indicator: @percentage{0.2f}%", x_range=(-0.5, 1.0))

# Add wedges (pie slices) based on the data
p.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='Indicator', source=year_overdose_data_df)

# Output to an HTML file
output_file(f"overdose_pie_chart_{year}.html")

# Hide axis and grid lines
p.axis.axis_label = None
p.axis.visible = False
p.grid.grid_line_color = None

# Show the plot
show(p)

# %%
# YEAR 2023######################################## #####YEAR 2023  ###############################

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_file
from bokeh.transform import cumsum
from bokeh.palettes import Category20c
import pandas as pd
import numpy as np

# Step 1: Pull data for the year 2023
year = 2023
year_data = Clean_Overdose_df[Clean_Overdose_df['Year'] == year]

# Step 2: Group the data by 'Indicator' and sum 'Data Value' for the specific year
year_overdose_data = year_data.groupby('Indicator')['Data Value'].sum().dropna()

# Step 3: Convert data to a DataFrame and calculate angles for pie slices
year_overdose_data_df = pd.DataFrame(year_overdose_data.reset_index(name='value'))
year_overdose_data_df['angle'] = year_overdose_data_df['value'] / year_overdose_data_df['value'].sum() * 2 * np.pi
year_overdose_data_df['percentage'] = (year_overdose_data_df['value'] / year_overdose_data_df['value'].sum()) * 100

# Step 4: Set up colors (up to 20 slices, more categories need more colors)
year_overdose_data_df['color'] = Category20c[len(year_overdose_data_df)]

# Step 5: Create the pie chart
p = figure(height=600, width=600, title=f"Percentage of Drug Use {year}", toolbar_location=None,
           tools="hover", tooltips="@Indicator: @percentage{0.2f}%", x_range=(-0.5, 1.0))

# Add wedges (pie slices) based on the data
p.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='Indicator', source=year_overdose_data_df)

# Output to an HTML file
output_file(f"overdose_pie_chart_{year}.html")

# Hide axis and grid lines
p.axis.axis_label = None
p.axis.visible = False
p.grid.grid_line_color = None

# Show the plot
show(p)

# %%
########################################        YEAR 2024  #########################

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_file
from bokeh.transform import cumsum
from bokeh.palettes import Category20c
import pandas as pd
import numpy as np

# Step 1: Pull data for the year 2024
year = 2024
year_data = Clean_Overdose_df[Clean_Overdose_df['Year'] == year]

# Step 2: Group the data by 'Indicator' and sum 'Data Value' for the specific year
year_overdose_data = year_data.groupby('Indicator')['Data Value'].sum().dropna()

# Step 3: Convert data to a DataFrame and calculate angles for pie slices
year_overdose_data_df = pd.DataFrame(year_overdose_data.reset_index(name='value'))
year_overdose_data_df['angle'] = year_overdose_data_df['value'] / year_overdose_data_df['value'].sum() * 2 * np.pi
year_overdose_data_df['percentage'] = (year_overdose_data_df['value'] / year_overdose_data_df['value'].sum()) * 100

# Step 4: Set up colors (up to 20 slices, more categories need more colors)
year_overdose_data_df['color'] = Category20c[len(year_overdose_data_df)]

# Step 5: Create the pie chart
p = figure(height=600, width=600, title=f"Percentage of Drug Use {year}", toolbar_location=None,
           tools="hover", tooltips="@Indicator: @percentage{0.2f}%", x_range=(-0.5, 1.0))

# Add wedges (pie slices) based on the data
p.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='Indicator', source=year_overdose_data_df)



# Output to an HTML file
output_file(f"overdose_pie_chart_{year}.html")

# Hide axis and grid lines
p.axis.axis_label = None
p.axis.visible = False
p.grid.grid_line_color = None

# Show the plot
show(p)

# %%
### Cells for testing####

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_file
from bokeh.transform import cumsum
from bokeh.palettes import Category20c
from bokeh.layouts import row
import pandas as pd
import numpy as np

# Step 1: Pull data for the year 2020 (or any other year)
year = 2020
year_data = Clean_Overdose_df[Clean_Overdose_df['Year'] == year]

# Step 2: Group the data by 'Indicator' and sum 'Data Value' for the specific year
year_overdose_data = year_data.groupby('Indicator')['Data Value'].sum().dropna()

# Step 3: Convert data to a DataFrame and calculate angles for pie slices
year_overdose_data_df = pd.DataFrame(year_overdose_data.reset_index(name='value'))
year_overdose_data_df['angle'] = year_overdose_data_df['value'] / year_overdose_data_df['value'].sum() * 2 * np.pi
year_overdose_data_df['percentage'] = (year_overdose_data_df['value'] / year_overdose_data_df['value'].sum()) * 100

# Step 4: Define custom colors (as per your request)
custom_colors = ['#FF5733', '#33FF57', '#3357FF', '#FF33A1', '#F3FF33']  # You can modify this list with more/less colors

# Assign custom colors to the 'color' column of the DataFrame
year_overdose_data_df['color'] = custom_colors[:len(year_overdose_data_df)]  # Only assign as many colors as needed

# Step 5: Create the pie chart
p = figure(height=600, width=600, title=f"Types of Overdoses in {year}", toolbar_location=None,
           tools="hover", tooltips="@Indicator: @percentage{0.2f}%", x_range=(-0.5, 1.0))

# Add wedges (pie slices) based on the data
p.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='Indicator', source=year_overdose_data_df)

# Hide axis and grid lines
p.axis.axis_label = None
p.axis.visible = False
p.grid.grid_line_color = None

# Step 6: Use layout to move the legend outside the plot
p.legend.location = "center_right"
p.legend.orientation = "vertical"

# Create the layout to position the pie chart
layout = row(p)

# Output to an HTML file
output_file(f"overdose_pie_chart_{year}_with_custom_colors.html")

# Show the plot
show(layout)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 25
#      22 custom_colors = ['#FF5733', '#33FF57', '#3357FF', '#FF33A1', '#F3FF33']  # You can modify this list with more/less colors
#      24 # Assign custom colors to the 'color' column of the DataFrame
# ---> 25 year_overdose_data_df['color'] = custom_colors[:len(year_overdose_data_df)]  # Only assign as many colors as needed
#      27 # Step 5: Create the pie chart
#      28 p = figure(height=600, width=600, title=f"Types of Overdoses in {year}", toolbar_location=None,
#      29            tools="hover", tooltips="@Indicator: @percentage{0.2f}%", x_range=(-0.5, 1.0))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
#    4529         and not isinstance(value.dtype, ExtensionDtype)
#    4530     ):
#    4531         # broadcast across multiple columns if necessary
#    4532         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5266, in DataFrame._sanitize_column(self, value)
#    5263     return _reindex_for_setitem(value, self.index)
#    5265 if is_list_like(value):
# -> 5266     com.require_length_match(value, self.index)
#    5267 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268 if (
#    5269     isinstance(value, Index)
#    5270     and value.dtype == "object"
#    (...)
#    5273     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5274     # this deprecation
#
# File ~\anaconda3\Lib\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (5) does not match length of index (10)
