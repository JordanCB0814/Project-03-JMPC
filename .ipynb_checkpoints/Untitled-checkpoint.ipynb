# %%
import pandas as pd

# Load the CSV file
overdose_data_df = pd.read_csv('VSRR_Provisional_Drug_Overdose_Death_Counts_20240930.csv')  # Replace 'filename.csv' with your actual file path

# Display the first few rows of the DataFrame
overdose_data_df.head(100)
# Out:
# C:\Users\knuck\AppData\Local\Temp\ipykernel_75608\3956341221.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   overdose_data_df = pd.read_csv('VSRR_Provisional_Drug_Overdose_Death_Counts_20240930.csv')  # Replace 'filename.csv' with your actual file path
#    State  Year  Month           Period  \
# 0     AK  2015  April  12 month-ending
# 1     AK  2015  April  12 month-ending
# 2     AK  2015  April  12 month-ending
# 3     AK  2015  April  12 month-ending
# 4     AK  2015  April  12 month-ending
# ..   ...   ...    ...              ...
# 95    AK  2015  March  12 month-ending
# 96    AK  2015    May  12 month-ending
# 97    AK  2015    May  12 month-ending
# 98    AK  2015    May  12 month-ending
# 99    AK  2015    May  12 month-ending
#
#                                             Indicator  Data Value  \
# 0            Natural & semi-synthetic opioids (T40.2)         NaN
# 1          Synthetic opioids, excl. methadone (T40.4)         NaN
# 2   Natural, semi-synthetic, & synthetic opioids, ...         NaN
# 3                                     Cocaine (T40.5)         NaN
# 4       Psychostimulants with abuse potential (T43.6)         NaN
# ..                                                ...         ...
# 95                     Number of Drug Overdose Deaths       125.0
# 96         Synthetic opioids, excl. methadone (T40.4)         NaN
# 97      Psychostimulants with abuse potential (T43.6)         NaN
# 98                                     Heroin (T40.1)         NaN
# 99                       Percent with drugs specified        86.4
#
#    Percent Complete  Percent Pending Investigation State Name  \
# 0               100                            0.0     Alaska
# 1               100                            0.0     Alaska
# 2               100                            0.0     Alaska
# 3               100                            0.0     Alaska
# 4               100                            0.0     Alaska
# ..              ...                            ...        ...
# 95              100                            0.0     Alaska
# 96              100                            0.0     Alaska
# 97              100                            0.0     Alaska
# 98              100                            0.0     Alaska
# 99              100                            0.0     Alaska
#
#                                              Footnote Footnote Symbol  \
# 0   Numbers may differ from published reports usin...              **
# 1   Numbers may differ from published reports usin...              **
# 2   Numbers may differ from published reports usin...              **
# 3   Numbers may differ from published reports usin...              **
# 4   Numbers may differ from published reports usin...              **
# ..                                                ...             ...
# 95  Numbers may differ from published reports usin...              **
# 96  Numbers may differ from published reports usin...              **
# 97  Numbers may differ from published reports usin...              **
# 98  Numbers may differ from published reports usin...              **
# 99  Numbers may differ from published reports usin...              **
#
#     Predicted Value
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 95            125.0
# 96              NaN
# 97              NaN
# 98              NaN
# 99              NaN
#
# [100 rows x 12 columns]

# %%
#Removing any NaN values we find within our rows
clean_overdose_data_df = overdose_data_df.dropna()
print(clean_overdose_data_df)
# Out:
#       State  Year     Month           Period  \
# 6        AK  2015     April  12 month-ending
# 15       AK  2015    August  12 month-ending
# 33       AK  2015  December  12 month-ending
# 41       AK  2015  February  12 month-ending
# 51       AK  2015   January  12 month-ending
# ...     ...   ...       ...              ...
# 68202    YC  2024     March  12 month-ending
# 68203    YC  2024     March  12 month-ending
# 68204    YC  2024     March  12 month-ending
# 68205    YC  2024     March  12 month-ending
# 68206    YC  2024     March  12 month-ending
#
#                                                Indicator  Data Value  \
# 6                         Number of Drug Overdose Deaths       126.0
# 15                        Number of Drug Overdose Deaths       124.0
# 33                        Number of Drug Overdose Deaths       121.0
# 41                        Number of Drug Overdose Deaths       127.0
# 51                        Number of Drug Overdose Deaths       126.0
# ...                                                  ...         ...
# 68202  Natural & semi-synthetic opioids, incl. methad...       654.0
# 68203      Psychostimulants with abuse potential (T43.6)       237.0
# 68204                                     Heroin (T40.1)       618.0
# 68205                        Opioids (T40.0-T40.4,T40.6)      2528.0
# 68206           Natural & semi-synthetic opioids (T40.2)       387.0
#
#       Percent Complete  Percent Pending Investigation     State Name  \
# 6                  100                       0.000000         Alaska
# 15                 100                       0.000000         Alaska
# 33                 100                       0.000000         Alaska
# 41                 100                       0.000000         Alaska
# 51                 100                       0.000000         Alaska
# ...                ...                            ...            ...
# 68202              100                       0.405502  New York City
# 68203              100                       0.405502  New York City
# 68204              100                       0.405502  New York City
# 68205              100                       0.405502  New York City
# 68206              100                       0.405502  New York City
#
#                                                 Footnote Footnote Symbol  \
# 6      Numbers may differ from published reports usin...              **
# 15     Numbers may differ from published reports usin...              **
# 33     Numbers may differ from published reports usin...              **
# 41     Numbers may differ from published reports usin...              **
# 51     Numbers may differ from published reports usin...              **
# ...                                                  ...             ...
# 68202              Underreported due to incomplete data.               *
# 68203              Underreported due to incomplete data.               *
# 68204              Underreported due to incomplete data.               *
# 68205              Underreported due to incomplete data.               *
# 68206              Underreported due to incomplete data.               *
#
#        Predicted Value
# 6                126.0
# 15               124.0
# 33               121.0
# 41               127.0
# 51               126.0
# ...                ...
# 68202            685.0
# 68203            250.0
# 68204            648.0
# 68205           2653.0
# 68206            406.0
#
# [40389 rows x 12 columns]

# %%
clean_overdose_data_df.drop(columns=['Footnote', 'Footnote Symbol', 'Period'], inplace=True)
# Out:
# C:\Users\knuck\AppData\Local\Temp\ipykernel_75608\4220137667.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_overdose_data_df.drop(columns=['Footnote', 'Footnote Symbol', 'Period'], inplace=True)

# %%
clean_overdose_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40389 entries, 6 to 68206
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State                          40389 non-null  object
#  1   Year                           40389 non-null  int64
#  2   Month                          40389 non-null  object
#  3   Indicator                      40389 non-null  object
#  4   Data Value                     40389 non-null  float64
#  5   Percent Complete               40389 non-null  object
#  6   Percent Pending Investigation  40389 non-null  float64
#  7   State Name                     40389 non-null  object
#  8   Predicted Value                40389 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 3.1+ MB

# %%
#Reorganizing our Columns to be better alligned
Clean_Overdose_df = clean_overdose_data_df[['State', 'State Name', 'Year', 'Month', 'Indicator', 'Data Value', 'Percent Complete', 'Percent Pending Investigation', 'Predicted Value']]

Clean_Overdose_df
# Out:
#       State     State Name  Year     Month  \
# 6        AK         Alaska  2015     April
# 15       AK         Alaska  2015    August
# 33       AK         Alaska  2015  December
# 41       AK         Alaska  2015  February
# 51       AK         Alaska  2015   January
# ...     ...            ...   ...       ...
# 68202    YC  New York City  2024     March
# 68203    YC  New York City  2024     March
# 68204    YC  New York City  2024     March
# 68205    YC  New York City  2024     March
# 68206    YC  New York City  2024     March
#
#                                                Indicator  Data Value  \
# 6                         Number of Drug Overdose Deaths       126.0
# 15                        Number of Drug Overdose Deaths       124.0
# 33                        Number of Drug Overdose Deaths       121.0
# 41                        Number of Drug Overdose Deaths       127.0
# 51                        Number of Drug Overdose Deaths       126.0
# ...                                                  ...         ...
# 68202  Natural & semi-synthetic opioids, incl. methad...       654.0
# 68203      Psychostimulants with abuse potential (T43.6)       237.0
# 68204                                     Heroin (T40.1)       618.0
# 68205                        Opioids (T40.0-T40.4,T40.6)      2528.0
# 68206           Natural & semi-synthetic opioids (T40.2)       387.0
#
#       Percent Complete  Percent Pending Investigation  Predicted Value
# 6                  100                       0.000000            126.0
# 15                 100                       0.000000            124.0
# 33                 100                       0.000000            121.0
# 41                 100                       0.000000            127.0
# 51                 100                       0.000000            126.0
# ...                ...                            ...              ...
# 68202              100                       0.405502            685.0
# 68203              100                       0.405502            250.0
# 68204              100                       0.405502            648.0
# 68205              100                       0.405502           2653.0
# 68206              100                       0.405502            406.0
#
# [40389 rows x 9 columns]

# %%
# !pip install folium

import folium

# Create a map centered at a latitude and longitude (approximate center of the USA)
m = folium.Map(location=[37.0902, -95.7129], zoom_start=4)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12cb8f79c8d7bc4d8c4fda7381b55306 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12cb8f79c8d7bc4d8c4fda7381b55306&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12cb8f79c8d7bc4d8c4fda7381b55306 = L.map(
#                 &quot;map_12cb8f79c8d7bc4d8c4fda7381b55306&quot;,
#                 {
#                     center: [37.0902, -95.7129],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a64d0e3d3919925d0955fd53991c24b4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a64d0e3d3919925d0955fd53991c24b4.addTo(map_12cb8f79c8d7bc4d8c4fda7381b55306);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
print(Clean_Overdose_df.head())
print(Clean_Overdose_df.columns)
# Out:
#    State State Name  Year     Month                       Indicator  \
# 6     AK     Alaska  2015     April  Number of Drug Overdose Deaths
# 15    AK     Alaska  2015    August  Number of Drug Overdose Deaths
# 33    AK     Alaska  2015  December  Number of Drug Overdose Deaths
# 41    AK     Alaska  2015  February  Number of Drug Overdose Deaths
# 51    AK     Alaska  2015   January  Number of Drug Overdose Deaths
#
#     Data Value Percent Complete  Percent Pending Investigation  \
# 6        126.0              100                            0.0
# 15       124.0              100                            0.0
# 33       121.0              100                            0.0
# 41       127.0              100                            0.0
# 51       126.0              100                            0.0
#
#     Predicted Value
# 6             126.0
# 15            124.0
# 33            121.0
# 41            127.0
# 51            126.0
# Index(['State', 'State Name', 'Year', 'Month', 'Indicator', 'Data Value',
#        'Percent Complete', 'Percent Pending Investigation', 'Predicted Value'],
#       dtype='object')

# %%
# Group by Year and State, then sum the Deaths
total_deaths_per_year_state = Clean_Overdose_df.groupby(['Year', 'State Name'])['Data Value'].sum().reset_index()
print(total_deaths_per_year_state)
# Out:
#      Year     State Name  Data Value
# 0    2015        Alabama      8818.0
# 1    2015         Alaska      2151.0
# 2    2015        Arizona     14590.0
# 3    2015       Arkansas      4616.0
# 4    2015     California     56001.0
# ..    ...            ...         ...
# 525  2024       Virginia     39126.0
# 526  2024     Washington     60941.0
# 527  2024  West Virginia     23602.0
# 528  2024      Wisconsin     28803.0
# 529  2024        Wyoming      1807.0
#
# [530 rows x 3 columns]

# %%
import pandas as pd

# Assuming you've already grouped your data
# total_deaths_per_year_state is the grouped DataFrame
total_deaths_per_year_state = Clean_Overdose_df.groupby(['Year', 'State Name'])['Data Value'].sum().reset_index()

# Loop through each unique year
for year in total_deaths_per_year_state['Year'].unique():
    # Filter data for the current year
    year_data = total_deaths_per_year_state[total_deaths_per_year_state['Year'] == year]
    
    # Define the file name for each year
    file_name = f'drug_overdose_deaths_{year}.csv'
    
    # Save the filtered data to a CSV file
    year_data.to_csv(file_name, index=False)

    print(f'Saved {file_name}')
# Out:
# Saved drug_overdose_deaths_2015.csv
# Saved drug_overdose_deaths_2016.csv
# Saved drug_overdose_deaths_2017.csv
# Saved drug_overdose_deaths_2018.csv
# Saved drug_overdose_deaths_2019.csv
# Saved drug_overdose_deaths_2020.csv
# Saved drug_overdose_deaths_2021.csv
# Saved drug_overdose_deaths_2022.csv
# Saved drug_overdose_deaths_2023.csv
# Saved drug_overdose_deaths_2024.csv

# %%
# Load the 2015 overdose data (replace with the correct file path)
overdose_2015 = pd.read_csv('drug_overdose_deaths_2015.csv')

# Create a DataFrame with state coordinates and states
state_coords = {
    'State Name': ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 
                   'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 
                   'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 
                   'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 
                   'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
    'Latitude': ['32.361538', '58.301935', '33.448457', '34.736009', '38.555605', '39.7391667', '41.767', '39.161921', '30.4518', '33.76', '21.30895', 
                 '43.613739', '39.783250', '39.790942', '41.590939', '39.04', '38.197274', '30.45809', '44.323535', '38.972945', '42.2352', '42.7335', 
                 '44.95', '32.320', '38.572954', '46.595805', '40.809868', '39.160949', '43.220093', '40.221741', '35.667231', '42.659829', '35.771', 
                 '48.813343', '39.962245', '35.482309', '44.931109', '40.269789', '41.82355', '34.000', '44.367966', '36.165', '30.266667', '40.7547', 
                 '44.26639', '37.54', '47.042418', '38.349497', '43.074722', '41.145548'],
    'Longitude': ['-86.279118', '-134.419740', '-112.073844', '-92.331122', '-121.468926', '-104.984167', '-72.677', '-75.526755', '-84.27277', 
                  '-84.39', '-157.826182', '-116.237651', '-89.650373', '-86.147685', '-93.620866', '-95.69', '-84.86311', '-91.140229', '-69.765261', 
                  '-76.501157', '-71.0275', '-84.5467', '-93.094', '-90.207', '-92.189283', '-112.027031', '-96.675345', '-119.753877', '-71.549127', 
                  '-74.756138', '-105.964575', '-73.781339', '-78.638', '-100.779004', '-83.000647', '-97.534994', '-123.029159', '-76.875613', 
                  '-71.422132', '-81.035', '-100.336378', '-86.784', '-97.75', '-111.892622', '-72.57194', '-77.46', '-122.893077', '-81.633294', 
                  '-89.384444', '-104.802042']
}

state_coords_2015_df = pd.DataFrame(state_coords)

# %%
# Ensure column names match between the two DataFrames
# Adjust the column name of the state in overdose_2015 if needed
overdose_2015.rename(columns={'State': 'State Name'}, inplace=True)

# Merge the datasets
merged_data_2015 = pd.merge(overdose_2015, state_coords_2015_df, on='State Name', how='left')

# %%
# Check for NaN values in Latitude and Longitude
print(merged_data_2015[['Latitude', 'Longitude']].isna().sum())

# Drop rows with NaN values in Latitude and Longitude
merged_data_clean_2015 = merged_data_2015.dropna(subset=['Latitude', 'Longitude'])

# Ensure data types are correct
merged_data_clean_2015['Latitude'] = merged_data_clean_2015['Latitude'].astype(float)
merged_data_clean_2015['Longitude'] = merged_data_clean_2015['Longitude'].astype(float)
# Out:
# Latitude     3
# Longitude    3
# dtype: int64
# C:\Users\knuck\AppData\Local\Temp\ipykernel_75608\3046130687.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data_clean_2015['Latitude'] = merged_data_clean_2015['Latitude'].astype(float)
# C:\Users\knuck\AppData\Local\Temp\ipykernel_75608\3046130687.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data_clean_2015['Longitude'] = merged_data_clean_2015['Longitude'].astype(float)

# %%
# Initialize the map, centered over the USA
m = folium.Map(location=[37.0902, -95.7129], zoom_start=4)

# Add markers for each state
for i, row in merged_data_clean_2015.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"{row['State Name']} - Overdose: {row['Data Value']}",
        tooltip=row['State Name']
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae6e2321ac18e88f7f3d385e9d8a4539 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae6e2321ac18e88f7f3d385e9d8a4539&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae6e2321ac18e88f7f3d385e9d8a4539 = L.map(
#                 &quot;map_ae6e2321ac18e88f7f3d385e9d8a4539&quot;,
#                 {
#                     center: [37.0902, -95.7129],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f12ddfccfa557ef9148526420676c701 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f12ddfccfa557ef9148526420676c701.addTo(map_ae6e2321ac18e88f7f3d385e9d8a4539);
#
#
#             var marker_02eea9e74c55f9c6e16f008c31bc1381 = L.marker(
#                 [32.361538, -86.279118],
#                 {}
#             ).addTo(map_ae6e2321ac18e88f7f3d385e9d8a4539);
#
#
#         var popup_da339c4c315fcb55da50133fd7cee9ee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8bad5c2d8269973fcd0f59d4d0bc5ffb = $(`&lt;div id=&quot;html_8bad5c2d8269973fcd0f59d4d0bc5ffb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alabama - Overdose: 8818.0&lt;/div&gt;`)[0];
#                 popup_da339c4c315fcb55da50133fd7cee9ee.setContent(html_8bad5c2d8269973fcd0f59d4d0bc5ffb);
#
#
#
#         marker_02eea9e74c55f9c6e16f008c31bc1381.bindPopup(popup_da339c4c315fcb55da50133fd7cee9ee)
#         ;
#
#
#
#
#             marker_02eea9e74c55f9c6e16f008c31bc1381.bindTooltip(
#                 `&lt;div&gt;
#                      Alabama
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_12837d10ff1d8a2c1a490effabe783da = L.marker(
#                 [58.301935, -134.41974],
#                 {}
#             ).addTo(map_ae6e2321ac18e88f7f3d385e9d8a4539);
#
#
#         var popup_8797cd579b8bd5a9b4128c312b527e2f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a114fb6d82e2572c408e660e936a916d = $(`&lt;div id=&quot;html_a114fb6d82e2572c408e660e936a916d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alaska - Overdose: 2151.0&lt;/div&gt;`)[0];
#                 popup_8797cd579b8bd5a9b4128c312b527e2f.setContent(html_a114fb6d82e2572c408e660e936a916d);
#
#
#
#         marker_12837d10ff1d8a2c1a490effabe783da.bindPopup(popup_8797cd579b8bd5a9b4128c312b527e2f)
#         ;
#
#
#
#
#             marker_12837d10ff1d8a2c1a490effabe783da.bindTooltip(
#                 `&lt;div&gt;
#                      Alaska
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cfc3c916adde09a56d24cd6194964862 = L.marker(
#                 [33.448457, -112.073844],
#                 {}
#             ).addTo(map_ae6e2321ac18e88f7f3d385e9d8a4539);
#
#
#         var popup_f77e60aa30120895b2a824399dab8794 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4a728982c70e8fb728e5e39d85f14896 = $(`&lt;div id=&quot;html_4a728982c70e8fb728e5e39d85f14896&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arizona - Overdose: 14590.0&lt;/div&gt;`)[0];
#                 popup_f77e60aa30120895b2a824399dab8794.setContent(html_4a728982c70e8fb728e5e39d85f14896);
#
#
#
#         marker_cfc3c916adde09a56d24cd6194964862.bindPopup(popup_f77e60aa30120895b2a824399dab8794)
#         ;
#
#
#
#
#             marker_cfc3c916adde09a56d24cd6194964862.bindTooltip(
#                 `&lt;div&gt;
#                      Arizona
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_486737b760bb1636fbfb1be49a07333b = L.marker(
#                 [34.736009, -92.331122],
#                 {}
#             ).addTo(map_ae6e2321ac18e88f7f3d385e9d8a4539);
#
#
#         var popup_752ac1efc319cae080d20b918494cb41 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_19c0000b8ec2840829bb61e5d4c7e89a = $(`&lt;div id=&quot;html_19c0000b8ec2840829bb61e5d4c7e89a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arkansas - Overdose: 4616.0&lt;/div&gt;`)[0];
#                 popup_752ac1efc319cae080d20b918494cb41.setContent(html_19c0000b8ec2840829bb61e5d4c7e89a);
#
#
#
#         marker_486737b760bb1636fbfb1be49a07333b.bindPopup(popup_752ac1efc319cae080d20b918494cb41)
#         ;
#
#
#
#
#             marker_486737b760bb1636fbfb1be49a07333b.bindTooltip(
#                 `&lt;div&gt;
#                      Arkansas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var

# %%
# Load the 2016 overdose data (replace with the correct file path)
overdose_2016 = pd.read_csv('drug_overdose_deaths_2016.csv')

# Create a DataFrame with state coordinates and states
state_coords = {
    'State Name': ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 
                   'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 
                   'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 
                   'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 
                   'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
    'Latitude': ['32.361538', '58.301935', '33.448457', '34.736009', '38.555605', '39.7391667', '41.767', '39.161921', '30.4518', '33.76', '21.30895', 
                 '43.613739', '39.783250', '39.790942', '41.590939', '39.04', '38.197274', '30.45809', '44.323535', '38.972945', '42.2352', '42.7335', 
                 '44.95', '32.320', '38.572954', '46.595805', '40.809868', '39.160949', '43.220093', '40.221741', '35.667231', '42.659829', '35.771', 
                 '48.813343', '39.962245', '35.482309', '44.931109', '40.269789', '41.82355', '34.000', '44.367966', '36.165', '30.266667', '40.7547', 
                 '44.26639', '37.54', '47.042418', '38.349497', '43.074722', '41.145548'],
    'Longitude': ['-86.279118', '-134.419740', '-112.073844', '-92.331122', '-121.468926', '-104.984167', '-72.677', '-75.526755', '-84.27277', 
                  '-84.39', '-157.826182', '-116.237651', '-89.650373', '-86.147685', '-93.620866', '-95.69', '-84.86311', '-91.140229', '-69.765261', 
                  '-76.501157', '-71.0275', '-84.5467', '-93.094', '-90.207', '-92.189283', '-112.027031', '-96.675345', '-119.753877', '-71.549127', 
                  '-74.756138', '-105.964575', '-73.781339', '-78.638', '-100.779004', '-83.000647', '-97.534994', '-123.029159', '-76.875613', 
                  '-71.422132', '-81.035', '-100.336378', '-86.784', '-97.75', '-111.892622', '-72.57194', '-77.46', '-122.893077', '-81.633294', 
                  '-89.384444', '-104.802042']
}

state_coords_2016_df = pd.DataFrame(state_coords)

# %%
# Ensure column names match between the two DataFrames
# Adjust the column name of the state in overdose_2015 if needed
overdose_2016.rename(columns={'State': 'State Name'}, inplace=True)

# Merge the datasets
merged_data_2016 = pd.merge(overdose_2016, state_coords_2016_df, on='State Name', how='left')

# %%
# Check for NaN values in Latitude and Longitude
print(merged_data_2016[['Latitude', 'Longitude']].isna().sum())

# Drop rows with NaN values in Latitude and Longitude
merged_data_clean_2016 = merged_data_2016.dropna(subset=['Latitude', 'Longitude'])

# Ensure data types are correct
merged_data_clean_2016['Latitude'] = merged_data_clean_2016['Latitude'].astype(float)
merged_data_clean_2016['Longitude'] = merged_data_clean_2016['Longitude'].astype(float)
# Out:
# Latitude     3
# Longitude    3
# dtype: int64
# C:\Users\knuck\AppData\Local\Temp\ipykernel_75608\2149932329.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data_clean_2016['Latitude'] = merged_data_clean_2016['Latitude'].astype(float)
# C:\Users\knuck\AppData\Local\Temp\ipykernel_75608\2149932329.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data_clean_2016['Longitude'] = merged_data_clean_2016['Longitude'].astype(float)

# %%
# Initialize the map, centered over the USA
m = folium.Map(location=[37.0902, -95.7129], zoom_start=4)

# Add markers for each state
for i, row in merged_data_clean_2016.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"{row['State Name']} - Overdose: {row['Data Value']}",
        tooltip=row['State Name']
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d48997fed33212c7293de2f73ac64d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d48997fed33212c7293de2f73ac64d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d48997fed33212c7293de2f73ac64d1 = L.map(
#                 &quot;map_2d48997fed33212c7293de2f73ac64d1&quot;,
#                 {
#                     center: [37.0902, -95.7129],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_46cebccabbd9c77712d7dd23dd265ad6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_46cebccabbd9c77712d7dd23dd265ad6.addTo(map_2d48997fed33212c7293de2f73ac64d1);
#
#
#             var marker_5fdfa3262fe3fa8f5039f35011057b39 = L.marker(
#                 [32.361538, -86.279118],
#                 {}
#             ).addTo(map_2d48997fed33212c7293de2f73ac64d1);
#
#
#         var popup_6f87c0b190ec4825231e30163f564c1d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0f441deb0d365eee647f489664e8b1d5 = $(`&lt;div id=&quot;html_0f441deb0d365eee647f489664e8b1d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alabama - Overdose: 8324.0&lt;/div&gt;`)[0];
#                 popup_6f87c0b190ec4825231e30163f564c1d.setContent(html_0f441deb0d365eee647f489664e8b1d5);
#
#
#
#         marker_5fdfa3262fe3fa8f5039f35011057b39.bindPopup(popup_6f87c0b190ec4825231e30163f564c1d)
#         ;
#
#
#
#
#             marker_5fdfa3262fe3fa8f5039f35011057b39.bindTooltip(
#                 `&lt;div&gt;
#                      Alabama
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3dae76e9695b1ac7f596339f02ed5dfd = L.marker(
#                 [58.301935, -134.41974],
#                 {}
#             ).addTo(map_2d48997fed33212c7293de2f73ac64d1);
#
#
#         var popup_97b6614f5423ee994bb1cedacabff092 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_788652b805f1abc33725150ad86945c7 = $(`&lt;div id=&quot;html_788652b805f1abc33725150ad86945c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alaska - Overdose: 6432.0&lt;/div&gt;`)[0];
#                 popup_97b6614f5423ee994bb1cedacabff092.setContent(html_788652b805f1abc33725150ad86945c7);
#
#
#
#         marker_3dae76e9695b1ac7f596339f02ed5dfd.bindPopup(popup_97b6614f5423ee994bb1cedacabff092)
#         ;
#
#
#
#
#             marker_3dae76e9695b1ac7f596339f02ed5dfd.bindTooltip(
#                 `&lt;div&gt;
#                      Alaska
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2e066108f3e487d49ebae8240e8cb439 = L.marker(
#                 [33.448457, -112.073844],
#                 {}
#             ).addTo(map_2d48997fed33212c7293de2f73ac64d1);
#
#
#         var popup_b1c2280335c0f31775f96974be9157c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5594fa4cbd68533e644d84ff661f534a = $(`&lt;div id=&quot;html_5594fa4cbd68533e644d84ff661f534a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arizona - Overdose: 16403.0&lt;/div&gt;`)[0];
#                 popup_b1c2280335c0f31775f96974be9157c9.setContent(html_5594fa4cbd68533e644d84ff661f534a);
#
#
#
#         marker_2e066108f3e487d49ebae8240e8cb439.bindPopup(popup_b1c2280335c0f31775f96974be9157c9)
#         ;
#
#
#
#
#             marker_2e066108f3e487d49ebae8240e8cb439.bindTooltip(
#                 `&lt;div&gt;
#                      Arizona
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_24c1be1656e1fa07f2d93f5efc5472df = L.marker(
#                 [34.736009, -92.331122],
#                 {}
#             ).addTo(map_2d48997fed33212c7293de2f73ac64d1);
#
#
#         var popup_e19abfa902d21fb5c3bded5bca74b155 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a1340cad6d95f5d11cbba0c03d505457 = $(`&lt;div id=&quot;html_a1340cad6d95f5d11cbba0c03d505457&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arkansas - Overdose: 4513.0&lt;/div&gt;`)[0];
#                 popup_e19abfa902d21fb5c3bded5bca74b155.setContent(html_a1340cad6d95f5d11cbba0c03d505457);
#
#
#
#         marker_24c1be1656e1fa07f2d93f5efc5472df.bindPopup(popup_e19abfa902d21fb5c3bded5bca74b155)
#         ;
#
#
#
#
#             marker_24c1be1656e1fa07f2d93f5efc5472df.bindTooltip(
#                 `&lt;div&gt;
#                      Arkansas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var

# %%
# Load the 2017 overdose data (replace with the correct file path)
overdose_2017 = pd.read_csv('drug_overdose_deaths_2017.csv')

# Create a DataFrame with state coordinates and states
state_coords = {
    'State Name': ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 
                   'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 
                   'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 
                   'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 
                   'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
    'Latitude': ['32.361538', '58.301935', '33.448457', '34.736009', '38.555605', '39.7391667', '41.767', '39.161921', '30.4518', '33.76', '21.30895', 
                 '43.613739', '39.783250', '39.790942', '41.590939', '39.04', '38.197274', '30.45809', '44.323535', '38.972945', '42.2352', '42.7335', 
                 '44.95', '32.320', '38.572954', '46.595805', '40.809868', '39.160949', '43.220093', '40.221741', '35.667231', '42.659829', '35.771', 
                 '48.813343', '39.962245', '35.482309', '44.931109', '40.269789', '41.82355', '34.000', '44.367966', '36.165', '30.266667', '40.7547', 
                 '44.26639', '37.54', '47.042418', '38.349497', '43.074722', '41.145548'],
    'Longitude': ['-86.279118', '-134.419740', '-112.073844', '-92.331122', '-121.468926', '-104.984167', '-72.677', '-75.526755', '-84.27277', 
                  '-84.39', '-157.826182', '-116.237651', '-89.650373', '-86.147685', '-93.620866', '-95.69', '-84.86311', '-91.140229', '-69.765261', 
                  '-76.501157', '-71.0275', '-84.5467', '-93.094', '-90.207', '-92.189283', '-112.027031', '-96.675345', '-119.753877', '-71.549127', 
                  '-74.756138', '-105.964575', '-73.781339', '-78.638', '-100.779004', '-83.000647', '-97.534994', '-123.029159', '-76.875613', 
                  '-71.422132', '-81.035', '-100.336378', '-86.784', '-97.75', '-111.892622', '-72.57194', '-77.46', '-122.893077', '-81.633294', 
                  '-89.384444', '-104.802042']
}

state_coords_2017_df = pd.DataFrame(state_coords)

# %%
# Ensure column names match between the two DataFrames
# Adjust the column name of the state in overdose_2015 if needed
overdose_2017.rename(columns={'State': 'State Name'}, inplace=True)

# Merge the datasets
merged_data_2017 = pd.merge(overdose_2017, state_coords_2017_df, on='State Name', how='left')

# %%
# Check for NaN values in Latitude and Longitude
print(merged_data_2017[['Latitude', 'Longitude']].isna().sum())

# Drop rows with NaN values in Latitude and Longitude
merged_data_clean_2017 = merged_data_2017.dropna(subset=['Latitude', 'Longitude'])

# Ensure data types are correct
merged_data_clean_2017['Latitude'] = merged_data_clean_2017['Latitude'].astype(float)
merged_data_clean_2017['Longitude'] = merged_data_clean_2017['Longitude'].astype(float)
# Out:
# Latitude     3
# Longitude    3
# dtype: int64
# C:\Users\knuck\AppData\Local\Temp\ipykernel_75608\1342021708.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data_clean_2017['Latitude'] = merged_data_clean_2017['Latitude'].astype(float)
# C:\Users\knuck\AppData\Local\Temp\ipykernel_75608\1342021708.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data_clean_2017['Longitude'] = merged_data_clean_2017['Longitude'].astype(float)

# %%
# Initialize the map, centered over the USA
m = folium.Map(location=[37.0902, -95.7129], zoom_start=4)

# Add markers for each state
for i, row in merged_data_clean_2017.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"{row['State Name']} - Overdose: {row['Data Value']}",
        tooltip=row['State Name']
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7782936b21c7ac2fcd5553a90c592ffe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7782936b21c7ac2fcd5553a90c592ffe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7782936b21c7ac2fcd5553a90c592ffe = L.map(
#                 &quot;map_7782936b21c7ac2fcd5553a90c592ffe&quot;,
#                 {
#                     center: [37.0902, -95.7129],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ac558952b62ba732706a7971e8c309cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ac558952b62ba732706a7971e8c309cd.addTo(map_7782936b21c7ac2fcd5553a90c592ffe);
#
#
#             var marker_08734a0d0f5d51120642d5316c875879 = L.marker(
#                 [32.361538, -86.279118],
#                 {}
#             ).addTo(map_7782936b21c7ac2fcd5553a90c592ffe);
#
#
#         var popup_50637b5c8c8a599657d61c1ae3916a0b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c29eac3e639d97651e0aab9acc5311e6 = $(`&lt;div id=&quot;html_c29eac3e639d97651e0aab9acc5311e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alabama - Overdose: 9551.0&lt;/div&gt;`)[0];
#                 popup_50637b5c8c8a599657d61c1ae3916a0b.setContent(html_c29eac3e639d97651e0aab9acc5311e6);
#
#
#
#         marker_08734a0d0f5d51120642d5316c875879.bindPopup(popup_50637b5c8c8a599657d61c1ae3916a0b)
#         ;
#
#
#
#
#             marker_08734a0d0f5d51120642d5316c875879.bindTooltip(
#                 `&lt;div&gt;
#                      Alabama
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_34bb1c1abe7d278540821c947fac021e = L.marker(
#                 [58.301935, -134.41974],
#                 {}
#             ).addTo(map_7782936b21c7ac2fcd5553a90c592ffe);
#
#
#         var popup_05eed6ac58775f92db95749583b54e1c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ef4cdd3b682247e9f5c415014f63aa0b = $(`&lt;div id=&quot;html_ef4cdd3b682247e9f5c415014f63aa0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alaska - Overdose: 6184.0&lt;/div&gt;`)[0];
#                 popup_05eed6ac58775f92db95749583b54e1c.setContent(html_ef4cdd3b682247e9f5c415014f63aa0b);
#
#
#
#         marker_34bb1c1abe7d278540821c947fac021e.bindPopup(popup_05eed6ac58775f92db95749583b54e1c)
#         ;
#
#
#
#
#             marker_34bb1c1abe7d278540821c947fac021e.bindTooltip(
#                 `&lt;div&gt;
#                      Alaska
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f2d7e26129c2b377c70512b4128a9f02 = L.marker(
#                 [33.448457, -112.073844],
#                 {}
#             ).addTo(map_7782936b21c7ac2fcd5553a90c592ffe);
#
#
#         var popup_01c8d3280286c429eb3692564342427c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_99e6640de9eec6f6f75691bc788499e3 = $(`&lt;div id=&quot;html_99e6640de9eec6f6f75691bc788499e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arizona - Overdose: 42046.0&lt;/div&gt;`)[0];
#                 popup_01c8d3280286c429eb3692564342427c.setContent(html_99e6640de9eec6f6f75691bc788499e3);
#
#
#
#         marker_f2d7e26129c2b377c70512b4128a9f02.bindPopup(popup_01c8d3280286c429eb3692564342427c)
#         ;
#
#
#
#
#             marker_f2d7e26129c2b377c70512b4128a9f02.bindTooltip(
#                 `&lt;div&gt;
#                      Arizona
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5289dc89dd12fdbbee9549acf2bf47a1 = L.marker(
#                 [34.736009, -92.331122],
#                 {}
#             ).addTo(map_7782936b21c7ac2fcd5553a90c592ffe);
#
#
#         var popup_86132b433154c7e2cc455b200a4b6d2e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1d474d6cbf6cab2c2643121fe4b052aa = $(`&lt;div id=&quot;html_1d474d6cbf6cab2c2643121fe4b052aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arkansas - Overdose: 4775.0&lt;/div&gt;`)[0];
#                 popup_86132b433154c7e2cc455b200a4b6d2e.setContent(html_1d474d6cbf6cab2c2643121fe4b052aa);
#
#
#
#         marker_5289dc89dd12fdbbee9549acf2bf47a1.bindPopup(popup_86132b433154c7e2cc455b200a4b6d2e)
#         ;
#
#
#
#
#             marker_5289dc89dd12fdbbee9549acf2bf47a1.bindTooltip(
#                 `&lt;div&gt;
#                      Arkansas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var

# %%
# Load the 2018 overdose data (replace with the correct file path)
overdose_2018 = pd.read_csv('drug_overdose_deaths_2018.csv')

# Create a DataFrame with state coordinates and states
state_coords = {
    'State Name': ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 
                   'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 
                   'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 
                   'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 
                   'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
    'Latitude': ['32.361538', '58.301935', '33.448457', '34.736009', '38.555605', '39.7391667', '41.767', '39.161921', '30.4518', '33.76', '21.30895', 
                 '43.613739', '39.783250', '39.790942', '41.590939', '39.04', '38.197274', '30.45809', '44.323535', '38.972945', '42.2352', '42.7335', 
                 '44.95', '32.320', '38.572954', '46.595805', '40.809868', '39.160949', '43.220093', '40.221741', '35.667231', '42.659829', '35.771', 
                 '48.813343', '39.962245', '35.482309', '44.931109', '40.269789', '41.82355', '34.000', '44.367966', '36.165', '30.266667', '40.7547', 
                 '44.26639', '37.54', '47.042418', '38.349497', '43.074722', '41.145548'],
    'Longitude': ['-86.279118', '-134.419740', '-112.073844', '-92.331122', '-121.468926', '-104.984167', '-72.677', '-75.526755', '-84.27277', 
                  '-84.39', '-157.826182', '-116.237651', '-89.650373', '-86.147685', '-93.620866', '-95.69', '-84.86311', '-91.140229', '-69.765261', 
                  '-76.501157', '-71.0275', '-84.5467', '-93.094', '-90.207', '-92.189283', '-112.027031', '-96.675345', '-119.753877', '-71.549127', 
                  '-74.756138', '-105.964575', '-73.781339', '-78.638', '-100.779004', '-83.000647', '-97.534994', '-123.029159', '-76.875613', 
                  '-71.422132', '-81.035', '-100.336378', '-86.784', '-97.75', '-111.892622', '-72.57194', '-77.46', '-122.893077', '-81.633294', 
                  '-89.384444', '-104.802042']
}

state_coords_2018_df = pd.DataFrame(state_coords)

# %%
# Ensure column names match between the two DataFrames
# Adjust the column name of the state in overdose_2015 if needed
overdose_2018.rename(columns={'State': 'State Name'}, inplace=True)

# Merge the datasets
merged_data_2018 = pd.merge(overdose_2018, state_coords_2018_df, on='State Name', how='left')

# %%
# Check for NaN values in Latitude and Longitude
print(merged_data_2018[['Latitude', 'Longitude']].isna().sum())

# Drop rows with NaN values in Latitude and Longitude
merged_data_clean_2018 = merged_data_2018.dropna(subset=['Latitude', 'Longitude'])

# Ensure data types are correct
merged_data_clean_2018['Latitude'] = merged_data_clean_2018['Latitude'].astype(float)
merged_data_clean_2018['Longitude'] = merged_data_clean_2018['Longitude'].astype(float)
# Out:
# Latitude     3
# Longitude    3
# dtype: int64
# C:\Users\knuck\AppData\Local\Temp\ipykernel_75608\3926046512.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data_clean_2018['Latitude'] = merged_data_clean_2018['Latitude'].astype(float)
# C:\Users\knuck\AppData\Local\Temp\ipykernel_75608\3926046512.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data_clean_2018['Longitude'] = merged_data_clean_2018['Longitude'].astype(float)

# %%
# Initialize the map, centered over the USA
m = folium.Map(location=[37.0902, -95.7129], zoom_start=4)

# Add markers for each state
for i, row in merged_data_clean_2018.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"{row['State Name']} - Overdose: {row['Data Value']}",
        tooltip=row['State Name']
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff8085011213225d27d59f9b2837ca3b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff8085011213225d27d59f9b2837ca3b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff8085011213225d27d59f9b2837ca3b = L.map(
#                 &quot;map_ff8085011213225d27d59f9b2837ca3b&quot;,
#                 {
#                     center: [37.0902, -95.7129],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e88d29f58d8e4261343e8c1e33cea75f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e88d29f58d8e4261343e8c1e33cea75f.addTo(map_ff8085011213225d27d59f9b2837ca3b);
#
#
#             var marker_56aea1c13276b98d6917ead34081db9a = L.marker(
#                 [32.361538, -86.279118],
#                 {}
#             ).addTo(map_ff8085011213225d27d59f9b2837ca3b);
#
#
#         var popup_87493bba81eda55db6bd86b55e9b34aa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_84b634950ea58b26a100dc82b3bf6727 = $(`&lt;div id=&quot;html_84b634950ea58b26a100dc82b3bf6727&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alabama - Overdose: 9198.0&lt;/div&gt;`)[0];
#                 popup_87493bba81eda55db6bd86b55e9b34aa.setContent(html_84b634950ea58b26a100dc82b3bf6727);
#
#
#
#         marker_56aea1c13276b98d6917ead34081db9a.bindPopup(popup_87493bba81eda55db6bd86b55e9b34aa)
#         ;
#
#
#
#
#             marker_56aea1c13276b98d6917ead34081db9a.bindTooltip(
#                 `&lt;div&gt;
#                      Alabama
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_56767dddb12d61b51ce2cf2edca9ccaa = L.marker(
#                 [58.301935, -134.41974],
#                 {}
#             ).addTo(map_ff8085011213225d27d59f9b2837ca3b);
#
#
#         var popup_deab1f3c57b6b4fb0482649a3763971d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_432ee30337216e770b5d501dc96cf212 = $(`&lt;div id=&quot;html_432ee30337216e770b5d501dc96cf212&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alaska - Overdose: 5645.0&lt;/div&gt;`)[0];
#                 popup_deab1f3c57b6b4fb0482649a3763971d.setContent(html_432ee30337216e770b5d501dc96cf212);
#
#
#
#         marker_56767dddb12d61b51ce2cf2edca9ccaa.bindPopup(popup_deab1f3c57b6b4fb0482649a3763971d)
#         ;
#
#
#
#
#             marker_56767dddb12d61b51ce2cf2edca9ccaa.bindTooltip(
#                 `&lt;div&gt;
#                      Alaska
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e70b712d4d39c20a5c0c23b0cba0a8b1 = L.marker(
#                 [33.448457, -112.073844],
#                 {}
#             ).addTo(map_ff8085011213225d27d59f9b2837ca3b);
#
#
#         var popup_30358161aec17d7ebbd5c0ad9d2aaf09 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0834fbc49d798bb1363308948b62a464 = $(`&lt;div id=&quot;html_0834fbc49d798bb1363308948b62a464&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arizona - Overdose: 68142.0&lt;/div&gt;`)[0];
#                 popup_30358161aec17d7ebbd5c0ad9d2aaf09.setContent(html_0834fbc49d798bb1363308948b62a464);
#
#
#
#         marker_e70b712d4d39c20a5c0c23b0cba0a8b1.bindPopup(popup_30358161aec17d7ebbd5c0ad9d2aaf09)
#         ;
#
#
#
#
#             marker_e70b712d4d39c20a5c0c23b0cba0a8b1.bindTooltip(
#                 `&lt;div&gt;
#                      Arizona
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b430b4217cb1cd2c8d3dd5b749c16cf3 = L.marker(
#                 [34.736009, -92.331122],
#                 {}
#             ).addTo(map_ff8085011213225d27d59f9b2837ca3b);
#
#
#         var popup_2f73d4f6a1f5bdbb8e1c8192bb618381 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f0b7bd3acd23a5cf264e9e1831a1813e = $(`&lt;div id=&quot;html_f0b7bd3acd23a5cf264e9e1831a1813e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arkansas - Overdose: 5286.0&lt;/div&gt;`)[0];
#                 popup_2f73d4f6a1f5bdbb8e1c8192bb618381.setContent(html_f0b7bd3acd23a5cf264e9e1831a1813e);
#
#
#
#         marker_b430b4217cb1cd2c8d3dd5b749c16cf3.bindPopup(popup_2f73d4f6a1f5bdbb8e1c8192bb618381)
#         ;
#
#
#
#
#             marker_b430b4217cb1cd2c8d3dd5b749c16cf3.bindTooltip(
#                 `&lt;div&gt;
#                      Arkansas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var

# %%
# Load the 2019 overdose data (replace with the correct file path)
overdose_2019 = pd.read_csv('drug_overdose_deaths_2019.csv')

# Create a DataFrame with state coordinates and states
state_coords = {
    'State Name': ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 
                   'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 
                   'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 
                   'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 
                   'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
    'Latitude': ['32.361538', '58.301935', '33.448457', '34.736009', '38.555605', '39.7391667', '41.767', '39.161921', '30.4518', '33.76', '21.30895', 
                 '43.613739', '39.783250', '39.790942', '41.590939', '39.04', '38.197274', '30.45809', '44.323535', '38.972945', '42.2352', '42.7335', 
                 '44.95', '32.320', '38.572954', '46.595805', '40.809868', '39.160949', '43.220093', '40.221741', '35.667231', '42.659829', '35.771', 
                 '48.813343', '39.962245', '35.482309', '44.931109', '40.269789', '41.82355', '34.000', '44.367966', '36.165', '30.266667', '40.7547', 
                 '44.26639', '37.54', '47.042418', '38.349497', '43.074722', '41.145548'],
    'Longitude': ['-86.279118', '-134.419740', '-112.073844', '-92.331122', '-121.468926', '-104.984167', '-72.677', '-75.526755', '-84.27277', 
                  '-84.39', '-157.826182', '-116.237651', '-89.650373', '-86.147685', '-93.620866', '-95.69', '-84.86311', '-91.140229', '-69.765261', 
                  '-76.501157', '-71.0275', '-84.5467', '-93.094', '-90.207', '-92.189283', '-112.027031', '-96.675345', '-119.753877', '-71.549127', 
                  '-74.756138', '-105.964575', '-73.781339', '-78.638', '-100.779004', '-83.000647', '-97.534994', '-123.029159', '-76.875613', 
                  '-71.422132', '-81.035', '-100.336378', '-86.784', '-97.75', '-111.892622', '-72.57194', '-77.46', '-122.893077', '-81.633294', 
                  '-89.384444', '-104.802042']
}

state_coords_2019_df = pd.DataFrame(state_coords)

# %%
# Ensure column names match between the two DataFrames
# Adjust the column name of the state in overdose_2019 if needed
overdose_2019.rename(columns={'State': 'State Name'}, inplace=True)

# Merge the datasets
merged_data_2019 = pd.merge(overdose_2019, state_coords_2019_df, on='State Name', how='left')

# %%
# Check for NaN values in Latitude and Longitude
print(merged_data_2019[['Latitude', 'Longitude']].isna().sum())

# Drop rows with NaN values in Latitude and Longitude
merged_data_clean_2019 = merged_data_2019.dropna(subset=['Latitude', 'Longitude'])

# Ensure data types are correct
merged_data_clean_2019['Latitude'] = merged_data_clean_2019['Latitude'].astype(float)
merged_data_clean_2019['Longitude'] = merged_data_clean_2019['Longitude'].astype(float)
# Out:
# Latitude     3
# Longitude    3
# dtype: int64
# C:\Users\knuck\AppData\Local\Temp\ipykernel_75608\55304193.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data_clean_2019['Latitude'] = merged_data_clean_2019['Latitude'].astype(float)
# C:\Users\knuck\AppData\Local\Temp\ipykernel_75608\55304193.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data_clean_2019['Longitude'] = merged_data_clean_2019['Longitude'].astype(float)

# %%
# Initialize the map, centered over the USA
m = folium.Map(location=[37.0902, -95.7129], zoom_start=4)

# Add markers for each state
for i, row in merged_data_clean_2019.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"{row['State Name']} - Overdose: {row['Data Value']}",
        tooltip=row['State Name']
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b1d83b987d89d304a754e442d658316 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b1d83b987d89d304a754e442d658316&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b1d83b987d89d304a754e442d658316 = L.map(
#                 &quot;map_2b1d83b987d89d304a754e442d658316&quot;,
#                 {
#                     center: [37.0902, -95.7129],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_38886f972f68a4868cb5dea16e704a43 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_38886f972f68a4868cb5dea16e704a43.addTo(map_2b1d83b987d89d304a754e442d658316);
#
#
#             var marker_c8203ad8ef182bdfbb17f055ad6ba9aa = L.marker(
#                 [32.361538, -86.279118],
#                 {}
#             ).addTo(map_2b1d83b987d89d304a754e442d658316);
#
#
#         var popup_8e23b8ffbdd3cd1c9733274bed8ebe7e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a1a269ebe2be5c3b81b0ea1dc6ad3c3f = $(`&lt;div id=&quot;html_a1a269ebe2be5c3b81b0ea1dc6ad3c3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alabama - Overdose: 8643.0&lt;/div&gt;`)[0];
#                 popup_8e23b8ffbdd3cd1c9733274bed8ebe7e.setContent(html_a1a269ebe2be5c3b81b0ea1dc6ad3c3f);
#
#
#
#         marker_c8203ad8ef182bdfbb17f055ad6ba9aa.bindPopup(popup_8e23b8ffbdd3cd1c9733274bed8ebe7e)
#         ;
#
#
#
#
#             marker_c8203ad8ef182bdfbb17f055ad6ba9aa.bindTooltip(
#                 `&lt;div&gt;
#                      Alabama
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_03f164044a4fcec45636b28ea4059f14 = L.marker(
#                 [58.301935, -134.41974],
#                 {}
#             ).addTo(map_2b1d83b987d89d304a754e442d658316);
#
#
#         var popup_6a10be2ee1b4cdcd818b1707a3c243a7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ae088e98bff98ba8ac94b6c959250e0a = $(`&lt;div id=&quot;html_ae088e98bff98ba8ac94b6c959250e0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alaska - Overdose: 5825.0&lt;/div&gt;`)[0];
#                 popup_6a10be2ee1b4cdcd818b1707a3c243a7.setContent(html_ae088e98bff98ba8ac94b6c959250e0a);
#
#
#
#         marker_03f164044a4fcec45636b28ea4059f14.bindPopup(popup_6a10be2ee1b4cdcd818b1707a3c243a7)
#         ;
#
#
#
#
#             marker_03f164044a4fcec45636b28ea4059f14.bindTooltip(
#                 `&lt;div&gt;
#                      Alaska
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d8ed37475a65568eab8e8a98e0924b93 = L.marker(
#                 [33.448457, -112.073844],
#                 {}
#             ).addTo(map_2b1d83b987d89d304a754e442d658316);
#
#
#         var popup_a3449ec1c2ec17026c552d8f9961ca8e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b587ef2d6f099385842efa0d32c817ff = $(`&lt;div id=&quot;html_b587ef2d6f099385842efa0d32c817ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arizona - Overdose: 78518.0&lt;/div&gt;`)[0];
#                 popup_a3449ec1c2ec17026c552d8f9961ca8e.setContent(html_b587ef2d6f099385842efa0d32c817ff);
#
#
#
#         marker_d8ed37475a65568eab8e8a98e0924b93.bindPopup(popup_a3449ec1c2ec17026c552d8f9961ca8e)
#         ;
#
#
#
#
#             marker_d8ed37475a65568eab8e8a98e0924b93.bindTooltip(
#                 `&lt;div&gt;
#                      Arizona
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_419cc7a9cc0fe3665a3921f0e543cb58 = L.marker(
#                 [34.736009, -92.331122],
#                 {}
#             ).addTo(map_2b1d83b987d89d304a754e442d658316);
#
#
#         var popup_3603995222a9a5a6ed80ffb125d99e7b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f0ec296565766c772208afafb295d33f = $(`&lt;div id=&quot;html_f0ec296565766c772208afafb295d33f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arkansas - Overdose: 4739.0&lt;/div&gt;`)[0];
#                 popup_3603995222a9a5a6ed80ffb125d99e7b.setContent(html_f0ec296565766c772208afafb295d33f);
#
#
#
#         marker_419cc7a9cc0fe3665a3921f0e543cb58.bindPopup(popup_3603995222a9a5a6ed80ffb125d99e7b)
#         ;
#
#
#
#
#             marker_419cc7a9cc0fe3665a3921f0e543cb58.bindTooltip(
#                 `&lt;div&gt;
#                      Arkansas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var

# %%
# Load the 2020 overdose data (replace with the correct file path)
overdose_2020 = pd.read_csv('drug_overdose_deaths_2020.csv')

# Create a DataFrame with state coordinates and states
state_coords = {
    'State Name': ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 
                   'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 
                   'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 
                   'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 
                   'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
    'Latitude': ['32.361538', '58.301935', '33.448457', '34.736009', '38.555605', '39.7391667', '41.767', '39.161921', '30.4518', '33.76', '21.30895', 
                 '43.613739', '39.783250', '39.790942', '41.590939', '39.04', '38.197274', '30.45809', '44.323535', '38.972945', '42.2352', '42.7335', 
                 '44.95', '32.320', '38.572954', '46.595805', '40.809868', '39.160949', '43.220093', '40.221741', '35.667231', '42.659829', '35.771', 
                 '48.813343', '39.962245', '35.482309', '44.931109', '40.269789', '41.82355', '34.000', '44.367966', '36.165', '30.266667', '40.7547', 
                 '44.26639', '37.54', '47.042418', '38.349497', '43.074722', '41.145548'],
    'Longitude': ['-86.279118', '-134.419740', '-112.073844', '-92.331122', '-121.468926', '-104.984167', '-72.677', '-75.526755', '-84.27277', 
                  '-84.39', '-157.826182', '-116.237651', '-89.650373', '-86.147685', '-93.620866', '-95.69', '-84.86311', '-91.140229', '-69.765261', 
                  '-76.501157', '-71.0275', '-84.5467', '-93.094', '-90.207', '-92.189283', '-112.027031', '-96.675345', '-119.753877', '-71.549127', 
                  '-74.756138', '-105.964575', '-73.781339', '-78.638', '-100.779004', '-83.000647', '-97.534994', '-123.029159', '-76.875613', 
                  '-71.422132', '-81.035', '-100.336378', '-86.784', '-97.75', '-111.892622', '-72.57194', '-77.46', '-122.893077', '-81.633294', 
                  '-89.384444', '-104.802042']
}

state_coords_2020_df = pd.DataFrame(state_coords)

# %%
# Ensure column names match between the two DataFrames
# Adjust the column name of the state in overdose_2020 if needed
overdose_2020.rename(columns={'State': 'State Name'}, inplace=True)

# Merge the datasets
merged_data_2020 = pd.merge(overdose_2020, state_coords_2020_df, on='State Name', how='left')

# %%
# Check for NaN values in Latitude and Longitude
print(merged_data_2020[['Latitude', 'Longitude']].isna().sum())

# Drop rows with NaN values in Latitude and Longitude
merged_data_clean_2020 = merged_data_2020.dropna(subset=['Latitude', 'Longitude'])

# Ensure data types are correct
merged_data_clean_2020['Latitude'] = merged_data_clean_2020['Latitude'].astype(float)
merged_data_clean_2020['Longitude'] = merged_data_clean_2020['Longitude'].astype(float)
# Out:
# Latitude     3
# Longitude    3
# dtype: int64
# C:\Users\knuck\AppData\Local\Temp\ipykernel_75608\3398441733.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data_clean_2020['Latitude'] = merged_data_clean_2020['Latitude'].astype(float)
# C:\Users\knuck\AppData\Local\Temp\ipykernel_75608\3398441733.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data_clean_2020['Longitude'] = merged_data_clean_2020['Longitude'].astype(float)

# %%
# Initialize the map, centered over the USA
m = folium.Map(location=[37.0902, -95.7129], zoom_start=4)

# Add markers for each state
for i, row in merged_data_clean_2020.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"{row['State Name']} - Overdose: {row['Data Value']}",
        tooltip=row['State Name']
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f23fc77908fd721ffa72b1092a244b01 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f23fc77908fd721ffa72b1092a244b01&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f23fc77908fd721ffa72b1092a244b01 = L.map(
#                 &quot;map_f23fc77908fd721ffa72b1092a244b01&quot;,
#                 {
#                     center: [37.0902, -95.7129],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70baedb017923e02839e8d606068dbbf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_70baedb017923e02839e8d606068dbbf.addTo(map_f23fc77908fd721ffa72b1092a244b01);
#
#
#             var marker_c82c8dfd525aec4b0b51ee5529e53ed6 = L.marker(
#                 [32.361538, -86.279118],
#                 {}
#             ).addTo(map_f23fc77908fd721ffa72b1092a244b01);
#
#
#         var popup_8f20634c0ec7fe354f9f535faff2d0dc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9805467a0004d8725d1b3b7505f8999f = $(`&lt;div id=&quot;html_9805467a0004d8725d1b3b7505f8999f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alabama - Overdose: 10624.0&lt;/div&gt;`)[0];
#                 popup_8f20634c0ec7fe354f9f535faff2d0dc.setContent(html_9805467a0004d8725d1b3b7505f8999f);
#
#
#
#         marker_c82c8dfd525aec4b0b51ee5529e53ed6.bindPopup(popup_8f20634c0ec7fe354f9f535faff2d0dc)
#         ;
#
#
#
#
#             marker_c82c8dfd525aec4b0b51ee5529e53ed6.bindTooltip(
#                 `&lt;div&gt;
#                      Alabama
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2c3d1491ee7271b65cef4c2377e9f839 = L.marker(
#                 [58.301935, -134.41974],
#                 {}
#             ).addTo(map_f23fc77908fd721ffa72b1092a244b01);
#
#
#         var popup_bcff7f81d0a4b93ac7e54648fad50cc1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d76997ad128fb485bbe26b2db098cf13 = $(`&lt;div id=&quot;html_d76997ad128fb485bbe26b2db098cf13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alaska - Overdose: 6232.0&lt;/div&gt;`)[0];
#                 popup_bcff7f81d0a4b93ac7e54648fad50cc1.setContent(html_d76997ad128fb485bbe26b2db098cf13);
#
#
#
#         marker_2c3d1491ee7271b65cef4c2377e9f839.bindPopup(popup_bcff7f81d0a4b93ac7e54648fad50cc1)
#         ;
#
#
#
#
#             marker_2c3d1491ee7271b65cef4c2377e9f839.bindTooltip(
#                 `&lt;div&gt;
#                      Alaska
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_751d6365c13b494e025a54c11ae64e12 = L.marker(
#                 [33.448457, -112.073844],
#                 {}
#             ).addTo(map_f23fc77908fd721ffa72b1092a244b01);
#
#
#         var popup_0a94f6b0e1f405b351487dff1a2ba6a0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9f06320110ee43f36dd68992246b9c5c = $(`&lt;div id=&quot;html_9f06320110ee43f36dd68992246b9c5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arizona - Overdose: 106644.0&lt;/div&gt;`)[0];
#                 popup_0a94f6b0e1f405b351487dff1a2ba6a0.setContent(html_9f06320110ee43f36dd68992246b9c5c);
#
#
#
#         marker_751d6365c13b494e025a54c11ae64e12.bindPopup(popup_0a94f6b0e1f405b351487dff1a2ba6a0)
#         ;
#
#
#
#
#             marker_751d6365c13b494e025a54c11ae64e12.bindTooltip(
#                 `&lt;div&gt;
#                      Arizona
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_84e72201d59c35c7965a8f099d529ed9 = L.marker(
#                 [34.736009, -92.331122],
#                 {}
#             ).addTo(map_f23fc77908fd721ffa72b1092a244b01);
#
#
#         var popup_9455b4476c71b9142b9f4ea25e74d9e3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_19d5ebe8e8e6ecb346355ec386414971 = $(`&lt;div id=&quot;html_19d5ebe8e8e6ecb346355ec386414971&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arkansas - Overdose: 5325.0&lt;/div&gt;`)[0];
#                 popup_9455b4476c71b9142b9f4ea25e74d9e3.setContent(html_19d5ebe8e8e6ecb346355ec386414971);
#
#
#
#         marker_84e72201d59c35c7965a8f099d529ed9.bindPopup(popup_9455b4476c71b9142b9f4ea25e74d9e3)
#         ;
#
#
#
#
#             marker_84e72201d59c35c7965a8f099d529ed9.bindTooltip(
#                 `&lt;div&gt;
#                      Arkansas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             v

# %%
# Load the 2021 overdose data (replace with the correct file path)
overdose_2021 = pd.read_csv('drug_overdose_deaths_2021.csv')

# Create a DataFrame with state coordinates and states
state_coords = {
    'State Name': ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 
                   'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 
                   'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 
                   'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 
                   'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
    'Latitude': ['32.361538', '58.301935', '33.448457', '34.736009', '38.555605', '39.7391667', '41.767', '39.161921', '30.4518', '33.76', '21.30895', 
                 '43.613739', '39.783250', '39.790942', '41.590939', '39.04', '38.197274', '30.45809', '44.323535', '38.972945', '42.2352', '42.7335', 
                 '44.95', '32.320', '38.572954', '46.595805', '40.809868', '39.160949', '43.220093', '40.221741', '35.667231', '42.659829', '35.771', 
                 '48.813343', '39.962245', '35.482309', '44.931109', '40.269789', '41.82355', '34.000', '44.367966', '36.165', '30.266667', '40.7547', 
                 '44.26639', '37.54', '47.042418', '38.349497', '43.074722', '41.145548'],
    'Longitude': ['-86.279118', '-134.419740', '-112.073844', '-92.331122', '-121.468926', '-104.984167', '-72.677', '-75.526755', '-84.27277', 
                  '-84.39', '-157.826182', '-116.237651', '-89.650373', '-86.147685', '-93.620866', '-95.69', '-84.86311', '-91.140229', '-69.765261', 
                  '-76.501157', '-71.0275', '-84.5467', '-93.094', '-90.207', '-92.189283', '-112.027031', '-96.675345', '-119.753877', '-71.549127', 
                  '-74.756138', '-105.964575', '-73.781339', '-78.638', '-100.779004', '-83.000647', '-97.534994', '-123.029159', '-76.875613', 
                  '-71.422132', '-81.035', '-100.336378', '-86.784', '-97.75', '-111.892622', '-72.57194', '-77.46', '-122.893077', '-81.633294', 
                  '-89.384444', '-104.802042']
}

state_coords_2021_df = pd.DataFrame(state_coords)

# %%
# Ensure column names match between the two DataFrames
# Adjust the column name of the state in overdose_2021 if needed
overdose_2021.rename(columns={'State': 'State Name'}, inplace=True)

# Merge the datasets
merged_data_2021 = pd.merge(overdose_2021, state_coords_2021_df, on='State Name', how='left')

# %%
# Check for NaN values in Latitude and Longitude
print(merged_data_2021[['Latitude', 'Longitude']].isna().sum())

# Drop rows with NaN values in Latitude and Longitude
merged_data_clean_2021 = merged_data_2021.dropna(subset=['Latitude', 'Longitude'])

# Ensure data types are correct
merged_data_clean_2021['Latitude'] = merged_data_clean_2021['Latitude'].astype(float)
merged_data_clean_2021['Longitude'] = merged_data_clean_2021['Longitude'].astype(float)
# Out:
# Latitude     3
# Longitude    3
# dtype: int64
# C:\Users\knuck\AppData\Local\Temp\ipykernel_75608\3542436395.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data_clean_2021['Latitude'] = merged_data_clean_2021['Latitude'].astype(float)
# C:\Users\knuck\AppData\Local\Temp\ipykernel_75608\3542436395.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data_clean_2021['Longitude'] = merged_data_clean_2021['Longitude'].astype(float)

# %%
# Initialize the map, centered over the USA
m = folium.Map(location=[37.0902, -95.7129], zoom_start=4)

# Add markers for each state
for i, row in merged_data_clean_2021.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"{row['State Name']} - Overdose: {row['Data Value']}",
        tooltip=row['State Name']
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1fd92ebdca06ee0c408a42391e9c0d03 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1fd92ebdca06ee0c408a42391e9c0d03&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1fd92ebdca06ee0c408a42391e9c0d03 = L.map(
#                 &quot;map_1fd92ebdca06ee0c408a42391e9c0d03&quot;,
#                 {
#                     center: [37.0902, -95.7129],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c4933de90617bba7f10eabcce2fea956 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c4933de90617bba7f10eabcce2fea956.addTo(map_1fd92ebdca06ee0c408a42391e9c0d03);
#
#
#             var marker_f79b718e6065b3a6eae338f40d725caf = L.marker(
#                 [32.361538, -86.279118],
#                 {}
#             ).addTo(map_1fd92ebdca06ee0c408a42391e9c0d03);
#
#
#         var popup_74c9fddff739397b7370c433eb401f92 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9a2aeb4ad8868d6f4e54dc98ceea5381 = $(`&lt;div id=&quot;html_9a2aeb4ad8868d6f4e54dc98ceea5381&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alabama - Overdose: 14096.0&lt;/div&gt;`)[0];
#                 popup_74c9fddff739397b7370c433eb401f92.setContent(html_9a2aeb4ad8868d6f4e54dc98ceea5381);
#
#
#
#         marker_f79b718e6065b3a6eae338f40d725caf.bindPopup(popup_74c9fddff739397b7370c433eb401f92)
#         ;
#
#
#
#
#             marker_f79b718e6065b3a6eae338f40d725caf.bindTooltip(
#                 `&lt;div&gt;
#                      Alabama
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_25de6c127f9747f51a07f7dd1efa98aa = L.marker(
#                 [58.301935, -134.41974],
#                 {}
#             ).addTo(map_1fd92ebdca06ee0c408a42391e9c0d03);
#
#
#         var popup_12ab648e849c6c357d021284537294b9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_db35d86416347e1bc417090b5d551811 = $(`&lt;div id=&quot;html_db35d86416347e1bc417090b5d551811&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alaska - Overdose: 11050.0&lt;/div&gt;`)[0];
#                 popup_12ab648e849c6c357d021284537294b9.setContent(html_db35d86416347e1bc417090b5d551811);
#
#
#
#         marker_25de6c127f9747f51a07f7dd1efa98aa.bindPopup(popup_12ab648e849c6c357d021284537294b9)
#         ;
#
#
#
#
#             marker_25de6c127f9747f51a07f7dd1efa98aa.bindTooltip(
#                 `&lt;div&gt;
#                      Alaska
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7f044f6917b6b7de6bfda2e5a5b03cec = L.marker(
#                 [33.448457, -112.073844],
#                 {}
#             ).addTo(map_1fd92ebdca06ee0c408a42391e9c0d03);
#
#
#         var popup_b0c527484dd8449a516bb4abd656b34d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ca6c8bdc87e6ee2a8ed7762781a749c1 = $(`&lt;div id=&quot;html_ca6c8bdc87e6ee2a8ed7762781a749c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arizona - Overdose: 126076.0&lt;/div&gt;`)[0];
#                 popup_b0c527484dd8449a516bb4abd656b34d.setContent(html_ca6c8bdc87e6ee2a8ed7762781a749c1);
#
#
#
#         marker_7f044f6917b6b7de6bfda2e5a5b03cec.bindPopup(popup_b0c527484dd8449a516bb4abd656b34d)
#         ;
#
#
#
#
#             marker_7f044f6917b6b7de6bfda2e5a5b03cec.bindTooltip(
#                 `&lt;div&gt;
#                      Arizona
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_90c1879d0629f496bad92f5f1bd608a4 = L.marker(
#                 [34.736009, -92.331122],
#                 {}
#             ).addTo(map_1fd92ebdca06ee0c408a42391e9c0d03);
#
#
#         var popup_3ef4ac2f857e200c33ba448cf12fb0fc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_76974f782cbc8c6121128a68ce789f31 = $(`&lt;div id=&quot;html_76974f782cbc8c6121128a68ce789f31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arkansas - Overdose: 11175.0&lt;/div&gt;`)[0];
#                 popup_3ef4ac2f857e200c33ba448cf12fb0fc.setContent(html_76974f782cbc8c6121128a68ce789f31);
#
#
#
#         marker_90c1879d0629f496bad92f5f1bd608a4.bindPopup(popup_3ef4ac2f857e200c33ba448cf12fb0fc)
#         ;
#
#
#
#
#             marker_90c1879d0629f496bad92f5f1bd608a4.bindTooltip(
#                 `&lt;div&gt;
#                      Arkansas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );

# %%
# Load the 2022 overdose data (replace with the correct file path)
overdose_2022 = pd.read_csv('drug_overdose_deaths_2022.csv')

# Create a DataFrame with state coordinates and states
state_coords = {
    'State Name': ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 
                   'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 
                   'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 
                   'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 
                   'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
    'Latitude': ['32.361538', '58.301935', '33.448457', '34.736009', '38.555605', '39.7391667', '41.767', '39.161921', '30.4518', '33.76', '21.30895', 
                 '43.613739', '39.783250', '39.790942', '41.590939', '39.04', '38.197274', '30.45809', '44.323535', '38.972945', '42.2352', '42.7335', 
                 '44.95', '32.320', '38.572954', '46.595805', '40.809868', '39.160949', '43.220093', '40.221741', '35.667231', '42.659829', '35.771', 
                 '48.813343', '39.962245', '35.482309', '44.931109', '40.269789', '41.82355', '34.000', '44.367966', '36.165', '30.266667', '40.7547', 
                 '44.26639', '37.54', '47.042418', '38.349497', '43.074722', '41.145548'],
    'Longitude': ['-86.279118', '-134.419740', '-112.073844', '-92.331122', '-121.468926', '-104.984167', '-72.677', '-75.526755', '-84.27277', 
                  '-84.39', '-157.826182', '-116.237651', '-89.650373', '-86.147685', '-93.620866', '-95.69', '-84.86311', '-91.140229', '-69.765261', 
                  '-76.501157', '-71.0275', '-84.5467', '-93.094', '-90.207', '-92.189283', '-112.027031', '-96.675345', '-119.753877', '-71.549127', 
                  '-74.756138', '-105.964575', '-73.781339', '-78.638', '-100.779004', '-83.000647', '-97.534994', '-123.029159', '-76.875613', 
                  '-71.422132', '-81.035', '-100.336378', '-86.784', '-97.75', '-111.892622', '-72.57194', '-77.46', '-122.893077', '-81.633294', 
                  '-89.384444', '-104.802042']
}

state_coords_2022_df = pd.DataFrame(state_coords)

# %%
# Ensure column names match between the two DataFrames
# Adjust the column name of the state in overdose_2022 if needed
overdose_2022.rename(columns={'State': 'State Name'}, inplace=True)

# Merge the datasets
merged_data_2022 = pd.merge(overdose_2022, state_coords_2022_df, on='State Name', how='left')

# %%
# Check for NaN values in Latitude and Longitude
print(merged_data_2022[['Latitude', 'Longitude']].isna().sum())

# Drop rows with NaN values in Latitude and Longitude
merged_data_clean_2022 = merged_data_2020.dropna(subset=['Latitude', 'Longitude'])

# Ensure data types are correct
merged_data_clean_2022['Latitude'] = merged_data_clean_2022['Latitude'].astype(float)
merged_data_clean_2022['Longitude'] = merged_data_clean_2022['Longitude'].astype(float)
# Out:
# Latitude     3
# Longitude    3
# dtype: int64
# C:\Users\knuck\AppData\Local\Temp\ipykernel_75608\1428475642.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data_clean_2022['Latitude'] = merged_data_clean_2022['Latitude'].astype(float)
# C:\Users\knuck\AppData\Local\Temp\ipykernel_75608\1428475642.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data_clean_2022['Longitude'] = merged_data_clean_2022['Longitude'].astype(float)

# %%
# Initialize the map, centered over the USA
m = folium.Map(location=[37.0902, -95.7129], zoom_start=4)

# Add markers for each state
for i, row in merged_data_clean_2022.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"{row['State Name']} - Overdose: {row['Data Value']}",
        tooltip=row['State Name']
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_066a60c1874e7dff866f0a10f1d47da5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_066a60c1874e7dff866f0a10f1d47da5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_066a60c1874e7dff866f0a10f1d47da5 = L.map(
#                 &quot;map_066a60c1874e7dff866f0a10f1d47da5&quot;,
#                 {
#                     center: [37.0902, -95.7129],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_857cc7d3af15f7269ee564193a466e00 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_857cc7d3af15f7269ee564193a466e00.addTo(map_066a60c1874e7dff866f0a10f1d47da5);
#
#
#             var marker_87960e29f4293369c658e9ba572a8394 = L.marker(
#                 [32.361538, -86.279118],
#                 {}
#             ).addTo(map_066a60c1874e7dff866f0a10f1d47da5);
#
#
#         var popup_86c6b6674e7a4831f29c239729a1c2ed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_236b55cccf62a8f5e80fe3ca8c66cce3 = $(`&lt;div id=&quot;html_236b55cccf62a8f5e80fe3ca8c66cce3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alabama - Overdose: 10624.0&lt;/div&gt;`)[0];
#                 popup_86c6b6674e7a4831f29c239729a1c2ed.setContent(html_236b55cccf62a8f5e80fe3ca8c66cce3);
#
#
#
#         marker_87960e29f4293369c658e9ba572a8394.bindPopup(popup_86c6b6674e7a4831f29c239729a1c2ed)
#         ;
#
#
#
#
#             marker_87960e29f4293369c658e9ba572a8394.bindTooltip(
#                 `&lt;div&gt;
#                      Alabama
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5fb6254f4b27c86f98b0b98d9c9641b9 = L.marker(
#                 [58.301935, -134.41974],
#                 {}
#             ).addTo(map_066a60c1874e7dff866f0a10f1d47da5);
#
#
#         var popup_fe68b67d79b8e6772145fe7f3d4d8448 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e7ff6ca8b0ebca0ab933d6707b71c91e = $(`&lt;div id=&quot;html_e7ff6ca8b0ebca0ab933d6707b71c91e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alaska - Overdose: 6232.0&lt;/div&gt;`)[0];
#                 popup_fe68b67d79b8e6772145fe7f3d4d8448.setContent(html_e7ff6ca8b0ebca0ab933d6707b71c91e);
#
#
#
#         marker_5fb6254f4b27c86f98b0b98d9c9641b9.bindPopup(popup_fe68b67d79b8e6772145fe7f3d4d8448)
#         ;
#
#
#
#
#             marker_5fb6254f4b27c86f98b0b98d9c9641b9.bindTooltip(
#                 `&lt;div&gt;
#                      Alaska
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_90b83c942ddb540f485633d403ebac99 = L.marker(
#                 [33.448457, -112.073844],
#                 {}
#             ).addTo(map_066a60c1874e7dff866f0a10f1d47da5);
#
#
#         var popup_3e7ad0fca8e630de98ae02ec48405246 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_696ff06ca743e562927b5e9b743376f6 = $(`&lt;div id=&quot;html_696ff06ca743e562927b5e9b743376f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arizona - Overdose: 106644.0&lt;/div&gt;`)[0];
#                 popup_3e7ad0fca8e630de98ae02ec48405246.setContent(html_696ff06ca743e562927b5e9b743376f6);
#
#
#
#         marker_90b83c942ddb540f485633d403ebac99.bindPopup(popup_3e7ad0fca8e630de98ae02ec48405246)
#         ;
#
#
#
#
#             marker_90b83c942ddb540f485633d403ebac99.bindTooltip(
#                 `&lt;div&gt;
#                      Arizona
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f42569300509dc007beba05424392c73 = L.marker(
#                 [34.736009, -92.331122],
#                 {}
#             ).addTo(map_066a60c1874e7dff866f0a10f1d47da5);
#
#
#         var popup_3b17473d1fcff2f8215fca0dd44a4941 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b9457ea0bf96c87baaf3f27e76bd00f = $(`&lt;div id=&quot;html_7b9457ea0bf96c87baaf3f27e76bd00f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arkansas - Overdose: 5325.0&lt;/div&gt;`)[0];
#                 popup_3b17473d1fcff2f8215fca0dd44a4941.setContent(html_7b9457ea0bf96c87baaf3f27e76bd00f);
#
#
#
#         marker_f42569300509dc007beba05424392c73.bindPopup(popup_3b17473d1fcff2f8215fca0dd44a4941)
#         ;
#
#
#
#
#             marker_f42569300509dc007beba05424392c73.bindTooltip(
#                 `&lt;div&gt;
#                      Arkansas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             v

# %%
# Load the 2023 overdose data (replace with the correct file path)
overdose_2023 = pd.read_csv('drug_overdose_deaths_2023.csv')

# Create a DataFrame with state coordinates and states
state_coords = {
    'State Name': ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 
                   'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 
                   'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 
                   'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 
                   'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
    'Latitude': ['32.361538', '58.301935', '33.448457', '34.736009', '38.555605', '39.7391667', '41.767', '39.161921', '30.4518', '33.76', '21.30895', 
                 '43.613739', '39.783250', '39.790942', '41.590939', '39.04', '38.197274', '30.45809', '44.323535', '38.972945', '42.2352', '42.7335', 
                 '44.95', '32.320', '38.572954', '46.595805', '40.809868', '39.160949', '43.220093', '40.221741', '35.667231', '42.659829', '35.771', 
                 '48.813343', '39.962245', '35.482309', '44.931109', '40.269789', '41.82355', '34.000', '44.367966', '36.165', '30.266667', '40.7547', 
                 '44.26639', '37.54', '47.042418', '38.349497', '43.074722', '41.145548'],
    'Longitude': ['-86.279118', '-134.419740', '-112.073844', '-92.331122', '-121.468926', '-104.984167', '-72.677', '-75.526755', '-84.27277', 
                  '-84.39', '-157.826182', '-116.237651', '-89.650373', '-86.147685', '-93.620866', '-95.69', '-84.86311', '-91.140229', '-69.765261', 
                  '-76.501157', '-71.0275', '-84.5467', '-93.094', '-90.207', '-92.189283', '-112.027031', '-96.675345', '-119.753877', '-71.549127', 
                  '-74.756138', '-105.964575', '-73.781339', '-78.638', '-100.779004', '-83.000647', '-97.534994', '-123.029159', '-76.875613', 
                  '-71.422132', '-81.035', '-100.336378', '-86.784', '-97.75', '-111.892622', '-72.57194', '-77.46', '-122.893077', '-81.633294', 
                  '-89.384444', '-104.802042']
}

state_coords_2023_df = pd.DataFrame(state_coords)

# %%
# Ensure column names match between the two DataFrames
# Adjust the column name of the state in overdose_2023 if needed
overdose_2023.rename(columns={'State': 'State Name'}, inplace=True)

# Merge the datasets
merged_data_2023 = pd.merge(overdose_2023, state_coords_2023_df, on='State Name', how='left')

# %%
# Check for NaN values in Latitude and Longitude
print(merged_data_2023[['Latitude', 'Longitude']].isna().sum())

# Drop rows with NaN values in Latitude and Longitude
merged_data_clean_2023 = merged_data_2020.dropna(subset=['Latitude', 'Longitude'])

# Ensure data types are correct
merged_data_clean_2023['Latitude'] = merged_data_clean_2023['Latitude'].astype(float)
merged_data_clean_2023['Longitude'] = merged_data_clean_2023['Longitude'].astype(float)
# Out:
# Latitude     3
# Longitude    3
# dtype: int64
# C:\Users\knuck\AppData\Local\Temp\ipykernel_75608\2468517841.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data_clean_2023['Latitude'] = merged_data_clean_2023['Latitude'].astype(float)
# C:\Users\knuck\AppData\Local\Temp\ipykernel_75608\2468517841.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data_clean_2023['Longitude'] = merged_data_clean_2023['Longitude'].astype(float)

# %%
# Initialize the map, centered over the USA
m = folium.Map(location=[37.0902, -95.7129], zoom_start=4)

# Add markers for each state
for i, row in merged_data_clean_2023.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"{row['State Name']} - Overdose: {row['Data Value']}",
        tooltip=row['State Name']
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4dd1758f99a7360c29c00bf7a9102a9a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4dd1758f99a7360c29c00bf7a9102a9a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4dd1758f99a7360c29c00bf7a9102a9a = L.map(
#                 &quot;map_4dd1758f99a7360c29c00bf7a9102a9a&quot;,
#                 {
#                     center: [37.0902, -95.7129],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e8fb108a630b19e1ec64321663662ca8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e8fb108a630b19e1ec64321663662ca8.addTo(map_4dd1758f99a7360c29c00bf7a9102a9a);
#
#
#             var marker_670a11143c27bfe0d6d04eec18443e72 = L.marker(
#                 [32.361538, -86.279118],
#                 {}
#             ).addTo(map_4dd1758f99a7360c29c00bf7a9102a9a);
#
#
#         var popup_8c32b6307c6ed4efaa4089c134a54a88 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_091258d36d050e2271b6b61164e78387 = $(`&lt;div id=&quot;html_091258d36d050e2271b6b61164e78387&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alabama - Overdose: 10624.0&lt;/div&gt;`)[0];
#                 popup_8c32b6307c6ed4efaa4089c134a54a88.setContent(html_091258d36d050e2271b6b61164e78387);
#
#
#
#         marker_670a11143c27bfe0d6d04eec18443e72.bindPopup(popup_8c32b6307c6ed4efaa4089c134a54a88)
#         ;
#
#
#
#
#             marker_670a11143c27bfe0d6d04eec18443e72.bindTooltip(
#                 `&lt;div&gt;
#                      Alabama
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ad4dc84993945f009885f03e7b8955ce = L.marker(
#                 [58.301935, -134.41974],
#                 {}
#             ).addTo(map_4dd1758f99a7360c29c00bf7a9102a9a);
#
#
#         var popup_6448929ecd13a8c776db562e1ad5a4a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4224850c4f288aafaba7674b275552a2 = $(`&lt;div id=&quot;html_4224850c4f288aafaba7674b275552a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alaska - Overdose: 6232.0&lt;/div&gt;`)[0];
#                 popup_6448929ecd13a8c776db562e1ad5a4a2.setContent(html_4224850c4f288aafaba7674b275552a2);
#
#
#
#         marker_ad4dc84993945f009885f03e7b8955ce.bindPopup(popup_6448929ecd13a8c776db562e1ad5a4a2)
#         ;
#
#
#
#
#             marker_ad4dc84993945f009885f03e7b8955ce.bindTooltip(
#                 `&lt;div&gt;
#                      Alaska
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ce7c12477cb2126bcd9aeeeab6203b3c = L.marker(
#                 [33.448457, -112.073844],
#                 {}
#             ).addTo(map_4dd1758f99a7360c29c00bf7a9102a9a);
#
#
#         var popup_ddd5b6c363d37d9dc4141e8c8adbf2ca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7fab408178e8ed4e726127cde90e8d4f = $(`&lt;div id=&quot;html_7fab408178e8ed4e726127cde90e8d4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arizona - Overdose: 106644.0&lt;/div&gt;`)[0];
#                 popup_ddd5b6c363d37d9dc4141e8c8adbf2ca.setContent(html_7fab408178e8ed4e726127cde90e8d4f);
#
#
#
#         marker_ce7c12477cb2126bcd9aeeeab6203b3c.bindPopup(popup_ddd5b6c363d37d9dc4141e8c8adbf2ca)
#         ;
#
#
#
#
#             marker_ce7c12477cb2126bcd9aeeeab6203b3c.bindTooltip(
#                 `&lt;div&gt;
#                      Arizona
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_218fcfc717448a498fcb7098de950b00 = L.marker(
#                 [34.736009, -92.331122],
#                 {}
#             ).addTo(map_4dd1758f99a7360c29c00bf7a9102a9a);
#
#
#         var popup_c290ef0f5b78aeccd97fb278c139dc4c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_568c4111cf8a140c7490abfc76cff8ad = $(`&lt;div id=&quot;html_568c4111cf8a140c7490abfc76cff8ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arkansas - Overdose: 5325.0&lt;/div&gt;`)[0];
#                 popup_c290ef0f5b78aeccd97fb278c139dc4c.setContent(html_568c4111cf8a140c7490abfc76cff8ad);
#
#
#
#         marker_218fcfc717448a498fcb7098de950b00.bindPopup(popup_c290ef0f5b78aeccd97fb278c139dc4c)
#         ;
#
#
#
#
#             marker_218fcfc717448a498fcb7098de950b00.bindTooltip(
#                 `&lt;div&gt;
#                      Arkansas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             v

# %%
# Load the 2024 overdose data (replace with the correct file path)
overdose_2024 = pd.read_csv('drug_overdose_deaths_2024.csv')

# Create a DataFrame with state coordinates and states
state_coords = {
    'State Name': ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 
                   'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 
                   'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 
                   'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 
                   'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
    'Latitude': ['32.361538', '58.301935', '33.448457', '34.736009', '38.555605', '39.7391667', '41.767', '39.161921', '30.4518', '33.76', '21.30895', 
                 '43.613739', '39.783250', '39.790942', '41.590939', '39.04', '38.197274', '30.45809', '44.323535', '38.972945', '42.2352', '42.7335', 
                 '44.95', '32.320', '38.572954', '46.595805', '40.809868', '39.160949', '43.220093', '40.221741', '35.667231', '42.659829', '35.771', 
                 '48.813343', '39.962245', '35.482309', '44.931109', '40.269789', '41.82355', '34.000', '44.367966', '36.165', '30.266667', '40.7547', 
                 '44.26639', '37.54', '47.042418', '38.349497', '43.074722', '41.145548'],
    'Longitude': ['-86.279118', '-134.419740', '-112.073844', '-92.331122', '-121.468926', '-104.984167', '-72.677', '-75.526755', '-84.27277', 
                  '-84.39', '-157.826182', '-116.237651', '-89.650373', '-86.147685', '-93.620866', '-95.69', '-84.86311', '-91.140229', '-69.765261', 
                  '-76.501157', '-71.0275', '-84.5467', '-93.094', '-90.207', '-92.189283', '-112.027031', '-96.675345', '-119.753877', '-71.549127', 
                  '-74.756138', '-105.964575', '-73.781339', '-78.638', '-100.779004', '-83.000647', '-97.534994', '-123.029159', '-76.875613', 
                  '-71.422132', '-81.035', '-100.336378', '-86.784', '-97.75', '-111.892622', '-72.57194', '-77.46', '-122.893077', '-81.633294', 
                  '-89.384444', '-104.802042']
}

state_coords_2024_df = pd.DataFrame(state_coords)

# %%
# Ensure column names match between the two DataFrames
# Adjust the column name of the state in overdose_2024 if needed
overdose_2024.rename(columns={'State': 'State Name'}, inplace=True)

# Merge the datasets
merged_data_2024 = pd.merge(overdose_2024, state_coords_2024_df, on='State Name', how='left')

# %%
# Check for NaN values in Latitude and Longitude
print(merged_data_2024[['Latitude', 'Longitude']].isna().sum())

# Drop rows with NaN values in Latitude and Longitude
merged_data_clean_2024 = merged_data_2024.dropna(subset=['Latitude', 'Longitude'])

# Ensure data types are correct
merged_data_clean_2024['Latitude'] = merged_data_clean_2024['Latitude'].astype(float)
merged_data_clean_2024['Longitude'] = merged_data_clean_2024['Longitude'].astype(float)
# Out:
# Latitude     3
# Longitude    3
# dtype: int64
# C:\Users\knuck\AppData\Local\Temp\ipykernel_75608\3899522491.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data_clean_2024['Latitude'] = merged_data_clean_2024['Latitude'].astype(float)
# C:\Users\knuck\AppData\Local\Temp\ipykernel_75608\3899522491.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data_clean_2024['Longitude'] = merged_data_clean_2024['Longitude'].astype(float)

# %%
# Initialize the map, centered over the USA
m = folium.Map(location=[37.0902, -95.7129], zoom_start=4)

# Add markers for each state
for i, row in merged_data_clean_2024.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"{row['State Name']} - Overdose: {row['Data Value']}",
        tooltip=row['State Name']
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e28d0d12b28ff2810db1d0e7fb70b187 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e28d0d12b28ff2810db1d0e7fb70b187&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e28d0d12b28ff2810db1d0e7fb70b187 = L.map(
#                 &quot;map_e28d0d12b28ff2810db1d0e7fb70b187&quot;,
#                 {
#                     center: [37.0902, -95.7129],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_18a7806e4100972d2d4fda8976b26486 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_18a7806e4100972d2d4fda8976b26486.addTo(map_e28d0d12b28ff2810db1d0e7fb70b187);
#
#
#             var marker_ebafe36adeda39077176185b45265bd8 = L.marker(
#                 [32.361538, -86.279118],
#                 {}
#             ).addTo(map_e28d0d12b28ff2810db1d0e7fb70b187);
#
#
#         var popup_b3587a21006a94e9756ce9362cb5d0c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9c43dff8ad3ed53a43321d0f14fc952f = $(`&lt;div id=&quot;html_9c43dff8ad3ed53a43321d0f14fc952f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alabama - Overdose: 23999.0&lt;/div&gt;`)[0];
#                 popup_b3587a21006a94e9756ce9362cb5d0c9.setContent(html_9c43dff8ad3ed53a43321d0f14fc952f);
#
#
#
#         marker_ebafe36adeda39077176185b45265bd8.bindPopup(popup_b3587a21006a94e9756ce9362cb5d0c9)
#         ;
#
#
#
#
#             marker_ebafe36adeda39077176185b45265bd8.bindTooltip(
#                 `&lt;div&gt;
#                      Alabama
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_be41c633d22c9dcbc75f9558dd5735ac = L.marker(
#                 [58.301935, -134.41974],
#                 {}
#             ).addTo(map_e28d0d12b28ff2810db1d0e7fb70b187);
#
#
#         var popup_1008a5913f0025876f1ce23908840a82 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3bf2fae0c84ace87f0620aba59eee82f = $(`&lt;div id=&quot;html_3bf2fae0c84ace87f0620aba59eee82f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alaska - Overdose: 6646.0&lt;/div&gt;`)[0];
#                 popup_1008a5913f0025876f1ce23908840a82.setContent(html_3bf2fae0c84ace87f0620aba59eee82f);
#
#
#
#         marker_be41c633d22c9dcbc75f9558dd5735ac.bindPopup(popup_1008a5913f0025876f1ce23908840a82)
#         ;
#
#
#
#
#             marker_be41c633d22c9dcbc75f9558dd5735ac.bindTooltip(
#                 `&lt;div&gt;
#                      Alaska
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cf320fb8555f5e6b629f582bb7610e1e = L.marker(
#                 [33.448457, -112.073844],
#                 {}
#             ).addTo(map_e28d0d12b28ff2810db1d0e7fb70b187);
#
#
#         var popup_d0c7c7d77b0e964209456393fedb4d56 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1b67b34537f2468e166895aec79aa00b = $(`&lt;div id=&quot;html_1b67b34537f2468e166895aec79aa00b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arizona - Overdose: 41709.0&lt;/div&gt;`)[0];
#                 popup_d0c7c7d77b0e964209456393fedb4d56.setContent(html_1b67b34537f2468e166895aec79aa00b);
#
#
#
#         marker_cf320fb8555f5e6b629f582bb7610e1e.bindPopup(popup_d0c7c7d77b0e964209456393fedb4d56)
#         ;
#
#
#
#
#             marker_cf320fb8555f5e6b629f582bb7610e1e.bindTooltip(
#                 `&lt;div&gt;
#                      Arizona
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_08708a1bd89bb2b88639783175defdfb = L.marker(
#                 [34.736009, -92.331122],
#                 {}
#             ).addTo(map_e28d0d12b28ff2810db1d0e7fb70b187);
#
#
#         var popup_fa22273a23cf7bb1b9e05fdff3b4a630 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b00541b5e973b2edc4138a3ad90e301c = $(`&lt;div id=&quot;html_b00541b5e973b2edc4138a3ad90e301c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arkansas - Overdose: 6902.0&lt;/div&gt;`)[0];
#                 popup_fa22273a23cf7bb1b9e05fdff3b4a630.setContent(html_b00541b5e973b2edc4138a3ad90e301c);
#
#
#
#         marker_08708a1bd89bb2b88639783175defdfb.bindPopup(popup_fa22273a23cf7bb1b9e05fdff3b4a630)
#         ;
#
#
#
#
#             marker_08708a1bd89bb2b88639783175defdfb.bindTooltip(
#                 `&lt;div&gt;
#                      Arkansas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             va
