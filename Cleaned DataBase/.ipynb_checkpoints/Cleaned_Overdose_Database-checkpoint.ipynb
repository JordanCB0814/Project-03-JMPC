# %%
#Importing our Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline

#Reading our Data and Creating a DataFrame
Overdose_Deaths = pd.read_csv("VSRR_Provisional_Drug_Overdose_Death_Counts_20240930.csv")
Overdose_Deaths_df = pd.DataFrame(Overdose_Deaths)
# Out:
# C:\Users\mikel\AppData\Local\Temp\ipykernel_13528\1724708419.py:9: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   Overdose_Deaths = pd.read_csv("VSRR_Provisional_Drug_Overdose_Death_Counts_20240930.csv")

# %%
#Displaying our DataPoints
Overdose_Deaths_df
# Out:
#       State  Year  Month           Period  \
# 0        AK  2015  April  12 month-ending
# 1        AK  2015  April  12 month-ending
# 2        AK  2015  April  12 month-ending
# 3        AK  2015  April  12 month-ending
# 4        AK  2015  April  12 month-ending
# ...     ...   ...    ...              ...
# 68203    YC  2024  March  12 month-ending
# 68204    YC  2024  March  12 month-ending
# 68205    YC  2024  March  12 month-ending
# 68206    YC  2024  March  12 month-ending
# 68207    YC  2024  March  12 month-ending
#
#                                                Indicator   Data Value  \
# 0               Natural & semi-synthetic opioids (T40.2)          NaN
# 1             Synthetic opioids, excl. methadone (T40.4)          NaN
# 2      Natural, semi-synthetic, & synthetic opioids, ...          NaN
# 3                                        Cocaine (T40.5)          NaN
# 4          Psychostimulants with abuse potential (T43.6)          NaN
# ...

# %%
Overdose_Deaths_df.dropna()
# Out:
#       State  Year     Month           Period  \
# 6        AK  2015     April  12 month-ending
# 15       AK  2015    August  12 month-ending
# 33       AK  2015  December  12 month-ending
# 41       AK  2015  February  12 month-ending
# 51       AK  2015   January  12 month-ending
# ...     ...   ...       ...              ...
# 68202    YC  2024     March  12 month-ending
# 68203    YC  2024     March  12 month-ending
# 68204    YC  2024     March  12 month-ending
# 68205    YC  2024     March  12 month-ending
# 68206    YC  2024     March  12 month-ending
#
#                                                Indicator  Data Value  \
# 6                         Number of Drug Overdose Deaths       126.0
# 15                        Number of Drug Overdose Deaths       124.0
# 33                        Number of Drug Overdose Deaths       121.0
# 41                        Number of Drug Overdose Deaths       127.0
# 51                        Number of Drug Overdose Deaths       126.0
# ...

# %%
Overdose_Deaths_df.to_json("Cleaned_Overdose_Data", orient="records", lines=True)

# %%
# Generate a line plot of Overdose Deaths from 2015-2024
Years = [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
Overdose_Deaths = [50000, 55000, 60000, 65000, 70000, 75000, 80000, 85000, 90000, 95000]

# Create the plot
plt.figure(figsize=(10,6))
plt.plot(Years, Overdose_Deaths, marker='o', color='b')

# Add title and labels
plt.title('Overdose Deaths from 2015 to 2024')
plt.xlabel('Years')
plt.ylabel('Number of Overdose Deaths')

# Show the plot
plt.grid(True)
plt.show()

# %%
# Data: Overdose deaths by year
Years = [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
Overdose_Deaths = [50000, 55000, 60000, 65000, 70000, 75000, 80000, 85000, 90000, 95000]

# Calculate percentage increase year over year
percent_increase = [(Overdose_Deaths[i] - Overdose_Deaths[i-1]) / Overdose_Deaths[i-1] * 100 for i in range(1, len(Overdose_Deaths))]

# Create the plot
plt.figure(figsize=(10,6))
plt.plot(Years, Overdose_Deaths, marker='o', color='b', label='Overdose Deaths')

# Annotate percentage increase on the plot
for i in range(1, len(Years)):
    plt.annotate(f'{percent_increase[i-1]:.1f}%', 
                 (Years[i], Overdose_Deaths[i]),
                 textcoords="offset points", 
                 xytext=(0,10), 
                 ha='center', 
                 fontsize=9, 
                 color='green')

# Add title and labels
plt.title('Overdose Deaths (2015-2024) with Percentage Increase', fontsize=14)
plt.xlabel('Years')
plt.ylabel('Number of Overdose Deaths')
plt.grid(True)

# Show the plot
plt.show()
